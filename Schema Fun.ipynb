# %%
import requests
from requests.auth import HTTPBasicAuth

def send_request():
    # Get netconf-state schemas
    # GET http://172.16.1.222:8008/api/operational/netconf-state/schemas

    try:
        response = requests.get(
            url="http://172.16.1.222:8008/api/operational/netconf-state/schemas",
            headers={
                "Accept": "application/vnd.yang.data+json",
            },
            auth=HTTPBasicAuth('cisco', 'cisco')
        )
        return response.content
    except requests.exceptions.RequestException:
        print('HTTP Request failed')

# %%
content = send_request()

# %%
import json

r = json.loads(content)

# %%
module_names = [s['identifier'] for s in r['ietf-netconf-monitoring:schemas']['schema']]

# %%
module_names
# Out:
# [u'ATM-FORUM-TC-MIB',
#  u'ATM-MIB',
#  u'ATM-TC-MIB',
#  u'BGP4-MIB',
#  u'BRIDGE-MIB',
#  u'CISCO-AAA-SERVER-MIB',
#  u'CISCO-AAA-SESSION-MIB',
#  u'CISCO-AAL5-MIB',
#  u'CISCO-ATM-EXT-MIB',
#  u'CISCO-ATM-PVCTRAP-EXTN-MIB',
#  u'CISCO-ATM-QOS-MIB',
#  u'CISCO-BGP-POLICY-ACCOUNTING-MIB',
#  u'CISCO-BGP4-MIB',
#  u'CISCO-BULK-FILE-MIB',
#  u'CISCO-CBP-TARGET-MIB',
#  u'CISCO-CBP-TARGET-TC-MIB',
#  u'CISCO-CBP-TC-MIB',
#  u'CISCO-CDP-MIB',
#  u'CISCO-CEF-MIB',
#  u'CISCO-CEF-TC',
#  u'CISCO-CLASS-BASED-QOS-MIB',
#  u'CISCO-CONFIG-COPY-MIB',
#  u'CISCO-CONFIG-MAN-MIB',
#  u'CISCO-CONTEXT-MAPPING-MIB',
#  u'CISCO-DATA-COLLECTION-MIB',
#  u'CISCO-DIAL-CONTROL-MIB',
#  u'CISCO-DOT3-OAM-MIB',
#  u'CISCO-DYNAMIC-TEMPLATE-MIB',
#  u'CISCO-DYNAMIC-TEMPLATE-TC-MIB',
#  u'CISCO-EIGRP-MIB',
#  u'CISCO-EMBEDDED-EVENT-MGR-MIB',
#  u'CISCO-ENHANCED-MEMPOOL-MIB',
#  u'CISCO-ENTITY-ALARM-MIB',
#  u'CISCO-ENTITY-EXT-MIB',
#  u'CISCO-ENTITY-FRU-CONTROL-MIB',
#  u'CISCO-ENTITY-PERFORMANCE-MIB',
#  u'CISCO-ENTITY-QFP-MIB',
#  u'CISCO-ENTITY-SENSOR-MIB',
#  u'CISCO-ENTITY-VENDORTYPE-OID-MIB',
#  u'CISCO-ETHER-CFM-MIB',
#  u'CISCO-ETHERLIKE-EXT-MIB',
#  u'CISCO-EVC-MIB',
#  u'CISCO-FIREWALL-TC',
#  u'CISCO-FLASH-MIB',
#  u'CISCO-FRAME-RELAY-MIB',
#  u'CISCO-FTP-CLIENT-MIB',
#  u'CISCO-HSRP-EXT-MIB',
#  u'CISCO-HSRP-MIB',
#  u'CISCO-IETF-ATM2-PVCTRAP-MIB',
#  u'CISCO-IETF-ATM2-PVCTRAP-MIB-EXTN',
#  u'CISCO-IETF-BFD-MIB',
#  u'CISCO-IETF-FRR-MIB',
#  u'CISCO-IETF-ISIS-MIB',
#  u'CISCO-IETF-MPLS-ID-STD-03-MIB',
#  u'CISCO-IETF-MPLS-TE-EXT-STD-03-MIB',
#  u'CISCO-IETF-PPVPN-MPLS-VPN-MIB',
#  u'CISCO-IETF-PW-ATM-MIB',
#  u'CISCO-IETF-PW-ENET-MIB',
#  u'CISCO-IETF-PW-MIB',
#  u'CISCO-IETF-PW-MPLS-MIB',
#  u'CISCO-IETF-PW-TC-MIB',
#  u'CISCO-IETF-PW-TDM-MIB',
#  u'CISCO-IF-EXTENSION-MIB',
#  u'CISCO-IGMP-FILTER-MIB',
#  u'CISCO-IMAGE-LICENSE-MGMT-MIB',
#  u'CISCO-IMAGE-MIB',
#  u'CISCO-IP-LOCAL-POOL-MIB',
#  u'CISCO-IP-TAP-MIB',
#  u'CISCO-IP-URPF-MIB',
#  u'CISCO-IPMROUTE-MIB',
#  u'CISCO-IPSEC-FLOW-MONITOR-MIB',
#  u'CISCO-IPSEC-MIB',
#  u'CISCO-IPSEC-POLICY-MAP-MIB',
#  u'CISCO-LAG-MIB',
#  u'CISCO-LICENSE-MGMT-MIB',
#  u'CISCO-MEDIA-GATEWAY-MIB',
#  u'CISCO-MPLS-LSR-EXT-STD-MIB',
#  u'CISCO-MPLS-TC-EXT-STD-MIB',
#  u'CISCO-MVPN-MIB',
#  u'CISCO-NBAR-PROTOCOL-DISCOVERY-MIB',
#  u'CISCO-NETFLOW-MIB',
#  u'CISCO-NETSYNC-MIB',
#  u'CISCO-NTP-MIB',
#  u'CISCO-OSPF-MIB',
#  u'CISCO-OSPF-TRAP-MIB',
#  u'CISCO-PIM-MIB',
#  u'CISCO-PING-MIB',
#  u'CISCO-PPPOE-MIB',
#  u'CISCO-PROCESS-MIB',
#  u'CISCO-PRODUCTS-MIB',
#  u'CISCO-PTP-MIB',
#  u'CISCO-QINQ-VLAN-MIB',
#  u'CISCO-QOS-PIB-MIB',
#  u'CISCO-RADIUS-EXT-MIB',
#  u'CISCO-RF-MIB',
#  u'CISCO-RTTMON-TC-MIB',
#  u'CISCO-SESS-BORDER-CTRLR-CALL-STATS-MIB',
#  u'CISCO-SESS-BORDER-CTRLR-STATS-MIB',
#  u'CISCO-SIP-UA-MIB',
#  u'CISCO-SMI',
#  u'CISCO-SONET-MIB',
#  u'CISCO-ST-TC',
#  u'CISCO-STP-EXTENSIONS-MIB',
#  u'CISCO-SUBSCRIBER-IDENTITY-TC-MIB',
#  u'CISCO-SUBSCRIBER-SESSION-MIB',
#  u'CISCO-SUBSCRIBER-SESSION-TC-MIB',
#  u'CISCO-SYSLOG-MIB',
#  u'CISCO-TAP2-MIB',
#  u'CISCO-TC',
#  u'CISCO-UBE-MIB',
#  u'CISCO-UNIFIED-FIREWALL-MIB',
#  u'CISCO-VLAN-IFTABLE-RELATIONSHIP-MIB',
#  u'CISCO-VLAN-MEMBERSHIP-MIB',
#  u'CISCO-VOICE-COMMON-DIAL-CONTROL-MIB',
#  u'CISCO-VOICE-DIAL-CONTROL-MIB',
#  u'CISCO-VOICE-DNIS-MIB',
#  u'CISCO-VPDN-MGMT-MIB',
#  u'CISCO-VTP-MIB',
#  u'DIAL-CONTROL-MIB',
#  u'DIFFSERV-DSCP-TC',
#  u'DIFFSERV-MIB',
#  u'DISMAN-EVENT-MIB',
#  u'DISMAN-EXPRESSION-MIB',
#  u'DRAFT-MSDP-MIB',
#  u'DS1-MIB',
#  u'DS3-MIB',
#  u'ENTITY-MIB',
#  u'ENTITY-SENSOR-MIB',
#  u'ENTITY-STATE-MIB',
#  u'ENTITY-STATE-TC-MIB',
#  u'ETHER-WIS',
#  u'EXPRESSION-MIB',
#  u'EtherLike-MIB',
#  u'FRAME-RELAY-DTE-MIB',
#  u'HCNUM-TC',
#  u'IANA-ADDRESS-FAMILY-NUMBERS-MIB',
#  u'IANA-RTPROTO-MIB',
#  u'IANAifType-MIB',
#  u'IANAifType-MIB',
#  u'IEEE8021-CFM-MIB',
#  u'IEEE8021-CFM-V2-MIB',
#  u'IEEE8021-TC-MIB',
#  u'IEEE8023-LAG-MIB',
#  u'IF-MIB',
#  u'IGMP-STD-MIB',
#  u'INET-ADDRESS-MIB',
#  u'INT-SERV-MIB',
#  u'INTEGRATED-SERVICES-MIB',
#  u'IP-FORWARD-MIB',
#  u'IP-MIB',
#  u'IPMROUTE-STD-MIB',
#  u'IPV6-FLOW-LABEL-MIB',
#  u'IPV6-TC',
#  u'LLDP-MIB',
#  u'MPLS-L3VPN-STD-MIB',
#  u'MPLS-LDP-GENERIC-STD-MIB',
#  u'MPLS-LDP-STD-MIB',
#  u'MPLS-LSR-STD-MIB',
#  u'MPLS-TC-MIB',
#  u'MPLS-TC-STD-MIB',
#  u'MPLS-TE-STD-MIB',
#  u'MPLS-VPN-MIB',
#  u'NHRP-MIB',
#  u'NOTIFICATION-LOG-MIB',
#  u'OLD-CISCO-SYS-MIB',
#  u'OSPF-MIB',
#  u'OSPF-TRAP-MIB',
#  u'P-BRIDGE-MIB',
#  u'PIM-MIB',
#  u'PerfHist-TC-MIB',
#  u'Q-BRIDGE-MIB',
#  u'RFC-1212',
#  u'RFC-1215',
#  u'RFC1155-SMI',
#  u'RFC1213-MIB',
#  u'RFC1271-MIB',
#  u'RFC1315-MIB',
#  u'RMON-MIB',
#  u'RMON2-MIB',
#  u'RSVP-MIB',
#  u'SNMP-COMMUNITY-MIB',
#  u'SNMP-FRAMEWORK-MIB',
#  u'SNMP-FRAMEWORK-MIB-ann',
#  u'SNMP-MPD-MIB',
#  u'SNMP-MPD-MIB-ann',
#  u'SNMP-NOTIFICATION-MIB',
#  u'SNMP-PROXY-MIB',
#  u'SNMP-TARGET-MIB',
#  u'SNMP-TARGET-MIB-ann',
#  u'SNMP-USER-BASED-SM-MIB',
#  u'SNMP-USER-BASED-SM-MIB-ann',
#  u'SNMP-VIEW-BASED-ACM-MIB',
#  u'SNMPv2-MIB',
#  u'SNMPv2-MIB-ann',
#  u'SNMPv2-SMI',
#  u'SNMPv2-TC',
#  u'SONET-MIB',
#  u'TCP-MIB',
#  u'TOKEN-RING-RMON-MIB',
#  u'TOKENRING-MIB',
#  u'TRANSPORT-ADDRESS-MIB',
#  u'TUNNEL-MIB',
#  u'UDP-MIB',
#  u'VPN-TC-STD-MIB',
#  u'cdp',
#  u'cisco-acl',
#  u'cisco-acl-oper',
#  u'cisco-acl-oper-ann',
#  u'cisco-bfd-state',
#  u'cisco-bfd-state-ann',
#  u'cisco-bgp-state',
#  u'cisco-bgp-state-ann',
#  u'cisco-bridge-common',
#  u'cisco-bridge-domain',
#  u'cisco-bridge-domain-ann',
#  u'cisco-cfm-stats',
#  u'cisco-cfm-stats-ann',
#  u'cisco-cfm-stats-dev',
#  u'cisco-checkpoint-archive',
#  u'cisco-checkpoint-archive-ann',
#  u'cisco-efp-stats',
#  u'cisco-efp-stats-ann',
#  u'cisco-environment',
#  u'cisco-environment-ann',
#  u'cisco-ethernet',
#  u'cisco-flow-monitor',
#  u'cisco-flow-monitor-ann',
#  u'cisco-ia',
#  u'cisco-ip-sla-stats',
#  u'cisco-ip-sla-stats-ann',
#  u'cisco-ip-sla-stats-dev',
#  u'cisco-lldp-state',
#  u'cisco-lldp-state-ann',
#  u'cisco-memory-stats',
#  u'cisco-memory-stats-ann',
#  u'cisco-mpls-fwd',
#  u'cisco-mpls-fwd-ann',
#  u'cisco-odm',
#  u'cisco-og',
#  u'cisco-ospf',
#  u'cisco-ospf-ann',
#  u'cisco-platform-software',
#  u'cisco-platform-software-ann',
#  u'cisco-policy',
#  u'cisco-policy-filters',
#  u'cisco-policy-target',
#  u'cisco-process-cpu',
#  u'cisco-process-cpu-ann',
#  u'cisco-process-memory',
#  u'cisco-process-memory-ann',
#  u'cisco-pw',
#  u'cisco-qos-action-marking-cfg',
#  u'cisco-qos-action-oper',
#  u'cisco-qos-action-oper-ann',
#  u'cisco-qos-action-qlimit-cfg',
#  u'cisco-qos-common',
#  u'cisco-routing-ext',
#  u'cisco-storm-control',
#  u'cisco-table-map',
#  u'cisco-virtual-service',
#  u'cisco-virtual-service-ann',
#  u'common-mpls-static',
#  u'common-mpls-static-ann',
#  u'common-mpls-types',
#  u'enable',
#  u'genet-state',
#  u'govern',
#  u'iana-crypt-hash',
#  u'iana-if-type',
#  u'ietf-access-control-list',
#  u'ietf-access-control-list-ann',
#  u'ietf-diffserv-action',
#  u'ietf-diffserv-classifier',
#  u'ietf-diffserv-classifier-ann',
#  u'ietf-diffserv-policy',
#  u'ietf-diffserv-policy-ann',
#  u'ietf-diffserv-target',
#  u'ietf-diffserv-target-ann',
#  u'ietf-inet-types',
#  u'ietf-inet-types',
#  u'ietf-interfaces',
#  u'ietf-interfaces-ann',
#  u'ietf-interfaces-ext',
#  u'ietf-ip',
#  u'ietf-ipv4-unicast-routing',
#  u'ietf-ipv4-unicast-routing-ann',
#  u'ietf-ipv6-unicast-routing',
#  u'ietf-ipv6-unicast-routing-ann',
#  u'ietf-key-chain',
#  u'ietf-netconf',
#  u'ietf-netconf-acm',
#  u'ietf-netconf-acm-ann',
#  u'ietf-netconf-monitoring',
#  u'ietf-netconf-monitoring-ann',
#  u'ietf-netconf-notifications',
#  u'ietf-netconf-notifications-ann',
#  u'ietf-netconf-with-defaults',
#  u'ietf-ospf',
#  u'ietf-ospf-ann',
#  u'ietf-ospf-ann',
#  u'ietf-packet-fields',
#  u'ietf-routing',
#  u'ietf-routing-ann',
#  u'ietf-yang-smiv2',
#  u'ietf-yang-smiv2',
#  u'ietf-yang-types',
#  u'ietf-yang-types',
#  u'ned',
#  u'nvo',
#  u'nvo-ann',
#  u'pim',
#  u'policy-attr',
#  u'policy-types',
#  u'tailf-acm',
#  u'tailf-cli-extensions',
#  u'tailf-common',
#  u'tailf-common-monitoring',
#  u'tailf-common-monitoring-ann',
#  u'tailf-common-query',
#  u'tailf-confd-monitoring',
#  u'tailf-confd-monitoring-ann',
#  u'tailf-meta-extensions',
#  u'tailf-netconf-inactive',
#  u'tailf-netconf-monitoring',
#  u'tailf-netconf-query',
#  u'tailf-netconf-transactions',
#  u'tailf-rest-error',
#  u'tailf-rest-query',
#  u'tailf-webui',
#  u'tailf-xsd-types']
