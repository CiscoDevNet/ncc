# %% [markdown]
# # BGP Shenanigans
#
# This notebook goes through a set of exanples with a CSR 1000v running IOS-XE 3.17 and the EFT netconf/yang interfaces. As such, please note that some details of the models used may differ as the openconfig-bgp model is not yet support on IOS-XE, meaning that the *native* model is being used.

# %% [markdown]
# ## Connecting to a Device

# %% [markdown]
# Let's define some variables:

# %%
#HOST = '172.26.170.252'
#PORT = 830
#USER = 'cisco'
#PASS = 'C1sdevops'

HOST = '172.16.1.222'
PORT = 2022
USER = 'cisco'
PASS = 'cisco'

# %% [markdown]
# Now let's establish a NETCONF session to that box using ncclient:

# %%
from ncclient import manager

def my_unknown_host_cb(host, fingerprint):
    return True
    
m = manager.connect(host=HOST, port=PORT, username=USER, password=PASS,
                    allow_agent=False,
                    look_for_keys=False,
                    hostkey_verify=False,
                    unknown_host_cb=my_unknown_host_cb)

# %% [markdown]
# ## Capabilities

# %% [markdown]
# Let's look at the capabilities presented by the thing we've just connected to:

# %%
print(m.server_capabilities)
# Out:
# ['urn:ietf:params:xml:ns:yang:smiv2:CISCO-CBP-TC-MIB?module=CISCO-CBP-TC-MIB&revision=2008-06-24', 'urn:ietf:params:xml:ns:yang:smiv2:RSVP-MIB?module=RSVP-MIB&revision=1998-08-25', 'urn:ietf:params:xml:ns:yang:smiv2:ATM-FORUM-TC-MIB?module=ATM-FORUM-TC-MIB', 'urn:ietf:params:xml:ns:yang:ietf-packet-fields?module=ietf-packet-fields&revision=2015-07-14', 'urn:ietf:params:xml:ns:yang:smiv2:CISCO-ENTITY-EXT-MIB?module=CISCO-ENTITY-EXT-MIB&revision=2008-11-24', 'urn:cisco:params:xml:ns:yang:cisco-qos-common?module=cisco-qos-common&revision=2015-05-09', 'urn:ietf:params:xml:ns:yang:smiv2:CISCO-NETSYNC-MIB?module=CISCO-NETSYNC-MIB&revision=2010-10-15', 'http://tail-f.com/ns/mibs/SNMPv2-MIB/200210160000Z?module=SNMPv2-MIB&revision=2002-10-16', 'urn:cisco:params:xml:ns:yang:cisco-environment?module=cisco-environment&revision=2015-04-09', 'http://tail-f.com/ns/mibs/SNMP-NOTIFICATION-MIB/200210140000Z?module=SNMP-NOTIFICATION-MIB&revision=2002-10-14', 'urn:ietf:params:xml:ns:yang:smiv2:CISCO-CBP-TARGET-TC-MIB?module=CISCO-CBP-TARGET-TC-MIB&revision=2006-03-24', 'urn:ietf:params:netconf:capability:notification:1.0', 'urn:ietf:params:xml:ns:yang:smiv2:DISMAN-EVENT-MIB?module=DISMAN-EVENT-MIB&revision=2000-10-16', 'urn:ietf:params:xml:ns:yang:smiv2:MPLS-LSR-STD-MIB?module=MPLS-LSR-STD-MIB&revision=2004-06-03', 'urn:ietf:params:xml:ns:yang:smiv2:CISCO-FRAME-RELAY-MIB?module=CISCO-FRAME-RELAY-MIB&revision=2000-10-13', 'urn:ietf:params:xml:ns:yang:smiv2:CISCO-ATM-PVCTRAP-EXTN-MIB?module=CISCO-ATM-PVCTRAP-EXTN-MIB&revision=2003-01-20', 'http://tail-f.com/ns/webui?module=tailf-webui&revision=2013-03-07', 'urn:ietf:params:xml:ns:yang:smiv2:CISCO-PRODUCTS-MIB?module=CISCO-PRODUCTS-MIB&revision=2014-11-06', 'urn:ietf:params:xml:ns:yang:smiv2:CISCO-UBE-MIB?module=CISCO-UBE-MIB&revision=2010-11-29', 'urn:ietf:params:xml:ns:yang:ietf-access-control-list?module=ietf-access-control-list&revision=2015-03-17', 'urn:ietf:params:netconf:capability:rollback-on-error:1.0', 'urn:ietf:params:xml:ns:yang:smiv2:RFC1213-MIB?module=RFC1213-MIB', 'urn:ietf:params:xml:ns:yang:smiv2:MPLS-LDP-GENERIC-STD-MIB?module=MPLS-LDP-GENERIC-STD-MIB&revision=2004-06-03', 'urn:ietf:params:xml:ns:yang:smiv2:CISCO-AAA-SESSION-MIB?module=CISCO-AAA-SESSION-MIB&revision=2006-03-21', 'http://tail-f.com/yang/common-monitoring?module=tailf-common-monitoring&revision=2013-06-14', 'urn:ietf:params:xml:ns:yang:smiv2:CISCO-RF-MIB?module=CISCO-RF-MIB&revision=2005-09-01', 'urn:ietf:params:xml:ns:yang:smiv2:ENTITY-MIB?module=ENTITY-MIB&revision=2005-08-10', 'urn:ietf:params:xml:ns:yang:smiv2:IP-FORWARD-MIB?module=IP-FORWARD-MIB&revision=1996-09-19', 'urn:ietf:params:xml:ns:yang:smiv2:CISCO-SUBSCRIBER-SESSION-TC-MIB?module=CISCO-SUBSCRIBER-SESSION-TC-MIB&revision=2012-01-27', 'urn:cisco:params:xml:ns:yang:cisco-efp-stats?module=cisco-efp-stats&revision=2015-07-07', 'urn:ietf:params:xml:ns:yang:smiv2:CISCO-PPPOE-MIB?module=CISCO-PPPOE-MIB&revision=2011-04-25', 'urn:cisco:params:xml:ns:yang:cisco-qos-action-qlimit-cfg?module=cisco-qos-action-qlimit-cfg&revision=2015-05-09&features=qos-grp-based-queuing-support,mpls-exp-based-queuing-support,disc-class-based-queuing-support', 'urn:ietf:params:xml:ns:yang:smiv2:CISCO-BULK-FILE-MIB?module=CISCO-BULK-FILE-MIB&revision=2002-06-10', 'urn:ietf:params:xml:ns:yang:iana-crypt-hash?module=iana-crypt-hash&revision=2014-04-04&features=crypt-hash-sha-512,crypt-hash-sha-256,crypt-hash-md5', 'urn:ietf:params:xml:ns:yang:smiv2:CISCO-NETFLOW-MIB?module=CISCO-NETFLOW-MIB&revision=2006-04-27', 'urn:ietf:params:xml:ns:yang:smiv2:EtherLike-MIB?module=EtherLike-MIB&revision=2003-09-19', 'urn:ios?module=ned&revision=2016-03-08', 'urn:ietf:params:xml:ns:yang:smiv2:CISCO-EIGRP-MIB?module=CISCO-EIGRP-MIB&revision=2004-11-16', 'urn:cisco:params:xml:ns:yang:table-map?module=cisco-table-map&revision=2015-05-19&features=table-map-template-support', 'http://tail-f.com/ns/mibs/SNMP-MPD-MIB/200210140000Z?module=SNMP-MPD-MIB&revision=2002-10-14', 'urn:ietf:params:xml:ns:yang:smiv2 ...

# %% [markdown]
# Ok, that's a bit messy, so let's tidy it up a bit and look, initially, at all the base netconf capabilities:

# %%
nc_caps = [c for c in m.server_capabilities if c.startswith('urn:ietf:params:netconf')]
for c in nc_caps:
    print(c)
# Out:
# urn:ietf:params:netconf:capability:notification:1.0
# urn:ietf:params:netconf:capability:rollback-on-error:1.0
# urn:ietf:params:netconf:capability:with-defaults:1.0?basic-mode=report-all
# urn:ietf:params:netconf:capability:interleave:1.0
# urn:ietf:params:netconf:capability:validate:1.0
# urn:ietf:params:netconf:capability:validate:1.1
# urn:ietf:params:netconf:base:1.0
# urn:ietf:params:netconf:base:1.1
# urn:ietf:params:netconf:capability:writable-running:1.0
# urn:ietf:params:netconf:capability:xpath:1.0

# %% [markdown]
# And now let's look at the capabilities that are related to model support:

# %%
import re

for c in m.server_capabilities:
    model = re.search('module=([^&]*)&', c)
    if model is not None:
        print("{}".format(model.group(1)))

        revision = re.search('revision=([0-9]{4}-[0-9]{2}-[0-9]{2})', c)
        if revision is not None:
            print("  revision = {}".format(revision.group(1)))

        deviations = re.search('deviations=([a-zA-Z0-9\-,]+)($|&)',c)
        if deviations is not None:
            print("  deviations = {}".format(deviations.group(1)))

        features = re.search('features=([a-zA-Z0-9\-,]+)($|&)',c)
        if features is not None:
            print("  features = {}".format(features.group(1)))
# Out:
# CISCO-CBP-TC-MIB
#   revision = 2008-06-24
# RSVP-MIB
#   revision = 1998-08-25
# ietf-packet-fields
#   revision = 2015-07-14
# CISCO-ENTITY-EXT-MIB
#   revision = 2008-11-24
# cisco-qos-common
#   revision = 2015-05-09
# CISCO-NETSYNC-MIB
#   revision = 2010-10-15
# SNMPv2-MIB
#   revision = 2002-10-16
# cisco-environment
#   revision = 2015-04-09
# SNMP-NOTIFICATION-MIB
#   revision = 2002-10-14
# CISCO-CBP-TARGET-TC-MIB
#   revision = 2006-03-24
# DISMAN-EVENT-MIB
#   revision = 2000-10-16
# MPLS-LSR-STD-MIB
#   revision = 2004-06-03
# CISCO-FRAME-RELAY-MIB
#   revision = 2000-10-13
# CISCO-ATM-PVCTRAP-EXTN-MIB
#   revision = 2003-01-20
# tailf-webui
#   revision = 2013-03-07
# CISCO-PRODUCTS-MIB
#   revision = 2014-11-06
# CISCO-UBE-MIB
#   revision = 2010-11-29
# ietf-access-control-list
#   revision = 2015-03-17
# MPLS-LDP-GENERIC-STD-MIB
#   revision = 2004-06-03
# CISCO-AAA-SESSION-MIB
#   revision = 2006-03-21
# tailf-common-monitoring
#   revision = 2013-06-14
# CISCO-RF-MIB
#   revision = 2005-09-01
# ENTITY-MIB
#   revision = 2005-08-10
# IP-FORWARD-MIB
#   revision = 1996-09-19
# CISCO-SUBSCRIBER-SESSION-TC-MIB
#   revision = 2012-01-27
# cisco-efp-stats
#   revision = 2015-07-07
# CISCO-PPPOE-MIB
#   revision = 2011-04-25
# cisco-qos-action-qlimit-cfg
#   revision = 2015-05-09
#   features = qos-grp-based-queuing-support,mpls-exp-based-queuing-support,disc-class-based-queuing-support
# CISCO-BULK-FILE-MIB
#   revision = 2002-06-10
# iana-crypt-hash
#   revision = 2014-04-04
#   features = crypt-hash-sha-512,crypt-hash-sha-256,crypt-hash-md5
# CISCO-NETFLOW-MIB
#   revision = 2006-04-27
# EtherLike-MIB
#   revision = 2003-09-19
# ned
#   revision = 2016-03-08
# CISCO-EIGRP-MIB
#   revision = 2004-11-16
# cisco-table-map
#   revision = 2015-05-19
#   features = table-map-template-support
# SNMP-MPD-MIB
#   revision = 2002-10-14
# CISCO-ENHANCED-MEMPOOL-MIB
#   revision = 2008-12-05
# CISCO-CDP-MIB
#   revision = 2005-03-21
# ietf-interfaces
#   revision = 2014-05-08
#   deviations = ietf-ip-devs
#   features = pre-provisioning,if-mib,arbitrary-names
# cisco-odm
#   revision = 2015-06-19
# CISCO-LAG-MIB
#   revision = 2010-10-20
# LLDP-MIB
#   revision = 2005-05-06
# tailf-confd-monitoring
#   revision = 2013-06-14
# common-mpls-types
#   revision = 2015-05-28
# CISCO-IETF-PW-MIB
#   revision = 2004-03-17
# CISCO-PROCESS-MIB
#   revision = 2010-05-06
# DS3-MIB
#   revision = 1998-08-01
# CISCO-OSPF-MIB
#   revision = 2003-07-18
# cisco-platform-software
#   revision = 2015-07-09
# cisco-ip-sla-stats-dev
#   revision = 2015-06-30
# CISCO-IETF-MPLS-TE-EXT-STD-03-MIB
#   revision = 2012-06-06
# cisco-flow-monitor
#   revision = 2015-10-26
# CISCO-OSPF-TRAP-MIB
#   revision = 2003-07-18
# ietf-diffserv-target
#   revision = 2015-04-07
#   features = target-inline-policy-config
# CISCO-NTP-MIB
#   revision = 2006-07-31
# CISCO-IETF-PW-MPLS-MIB
#   revision = 2003-02-26
# ietf-yang-types
#   revision = 2013-07-15
# CISCO-SYSLOG-MIB
#   revision = 2005-12-03
# CISCO-TAP2-MIB
#   revision = 2009-11-06
# CISCO-DYNAMIC-TEMPLATE-MIB
#   revision = 2007-09-06
# cisco-og
#   revision = 2015-05-04
#   features = og-service-support,og-security-support,og-port-support,og-network-support,og-network-range-support
# policy-attr
#   revision = 2015-04-27
# IEEE8023-LAG-MIB
#   revision = 2000-06-27
# cisco-process-memory
#   revision = 2015-04-09
# IEEE8021-CFM-V2-MIB
#   revision = 2008-10-15
# CISCO-MPLS-TC-EXT-STD-MIB
#   revision = 2012-02-22
# CISCO-CEF-MIB
#   revision = 2006-01-30
# cisco-qos-action-marking-cfg
#   revision = 2015-05-09
#   features = set-wlan-user-priority-support,set-vlan-inner-support,set-srp-priority-support,set-qos-grp-support,set-prec-tunnel-support,set-prec-support,set-mpls-exp-top-support,set-mpls-exp-imp-support,set-fr-fecn-becn-support,set-fr-de-support,set-dscp-tunnel-support,set-discard-class-support,set-dei-support,set-dei-imp-support,set-cos-support,set-cos-inner-suppport,set-atm-clp-support
# CISCO-DYNAMIC-TEMPLATE-TC-MIB
#   revision = 2012-01-27
# CISCO-IETF-MPLS-ID-STD-03-MIB
#   revision = 2012-06-07
# SNMP-VIEW-BASED-ACM-MIB
#   revision = 2002-10-16
# CISCO-VOICE-DNIS-MIB
#   revision = 2002-05-01
# cisco-routing-ext
#   revision = 2015-05-27
# ietf-netconf-monitoring
#   revision = 2010-10-04
# cisco-lldp-state
#   revision = 2015-04-09
# cisco-bfd-state
#   revision = 2015-04-09
# DISMAN-EXPRESSION-MIB
#   revision = 2000-10-16
# ietf-ipv4-unicast-routing
#   revision = 2015-05-25
# CISCO-FTP-CLIENT-MIB
#   revision = 2006-03-31
# CISCO-CONFIG-MAN-MIB
#   revision = 2007-04-27
# INTEGRATED-SERVICES-MIB
#   revision = 1995-11-03
# pim
#   revision = 2014-06-27
#   features = bsr,auto-rp
# CISCO-AAA-SERVER-MIB
#   revision = 2003-11-17
# CISCO-UNIFIED-FIREWALL-MIB
#   revision = 2005-09-22
# DS1-MIB
#   revision = 1998-08-01
# CISCO-IETF-BFD-MIB
#   revision = 2011-04-16
# CISCO-LICENSE-MGMT-MIB
#   revision = 2012-04-19
# CISCO-ENTITY-FRU-CONTROL-MIB
#   revision = 2013-08-19
# BRIDGE-MIB
#   revision = 2005-09-19
# CISCO-CEF-TC
#   revision = 2005-09-30
# ATM-MIB
#   revision = 1998-10-19
# CISCO-TC
#   revision = 2011-11-11
# EXPRESSION-MIB
#   revision = 2005-11-24
# cisco-ethernet
#   revision = 2014-05-12
# ietf-netconf-notifications
#   revision = 2012-02-06
# CISCO-IPSEC-FLOW-MONITOR-MIB
#   revision = 2007-10-24
# SNMP-PROXY-MIB
#   revision = 2002-10-14
# CISCO-BGP4-MIB
#   revision = 2010-09-30
# iana-if-type
#   revision = 2014-05-08
# HCNUM-TC
#   revision = 2000-06-08
# CISCO-CONFIG-COPY-MIB
#   revision = 2005-04-06
# CISCO-SIP-UA-MIB
#   revision = 2004-02-19
# CISCO-EVC-MIB
#   revision = 2012-05-21
# ietf-yang-smiv2
#   revision = 2012-06-22
# cisco-ip-sla-stats
#   revision = 2015-05-29
# cisco-qos-action-oper
#   revision = 2015-05-09
#   features = queue-peak-size-stats-support,priority-bandwidth-exceed-drops-support,marking-stats-support,drop-pkts-no-buffer-stats-support,drop-pkts-flow-stats-support,aggregate-priority-stats-support
# CISCO-DIAL-CONTROL-MIB
#   revision = 2005-05-26
# CISCO-SUBSCRIBER-IDENTITY-TC-MIB
#   revision = 2011-12-23
# DIFFSERV-DSCP-TC
#   revision = 2002-05-09
# tailf-acm
#   revision = 2013-03-07
# IANAifType-MIB
#   revision = 2006-03-31
# cisco-mpls-fwd
#   revision = 2015-04-09
# IGMP-STD-MIB
#   revision = 2000-09-28
# CISCO-CONTEXT-MAPPING-MIB
#   revision = 2008-11-22
# ENTITY-SENSOR-MIB
#   revision = 2002-12-16
# CISCO-IMAGE-LICENSE-MGMT-MIB
#   revision = 2007-10-16
# CISCO-CBP-TARGET-MIB
#   revision = 2006-05-24
# CISCO-QINQ-VLAN-MIB
#   revision = 2004-11-29
# CISCO-IPSEC-POLICY-MAP-MIB
#   revision = 2000-08-17
# IPV6-FLOW-LABEL-MIB
#   revision = 2003-08-28
# CISCO-HSRP-MIB
#   revision = 2010-09-06
# IPV6-TC
#   revision = 1998-12-01
# cisco-cfm-stats
#   revision = 2015-04-09
# CISCO-VOICE-COMMON-DIAL-CONTROL-MIB
#   revision = 2010-06-30
# CISCO-IPSEC-MIB
#   revision = 2000-08-07
# cisco-ia
#   revision = 2015-07-07
# SONET-MIB
#   revision = 2003-08-11
# CISCO-VOICE-DIAL-CONTROL-MIB
#   revision = 2012-05-15
# VPN-TC-STD-MIB
#   revision = 2005-11-15
# RMON-MIB
#   revision = 2000-05-11
# CISCO-IETF-FRR-MIB
#   revision = 2008-04-29
# CISCO-FLASH-MIB
#   revision = 2013-08-06
# IANA-RTPROTO-MIB
#   revision = 2000-09-26
# CISCO-IETF-ATM2-PVCTRAP-MIB-EXTN
#   revision = 2000-07-11
# cisco-policy-target
#   revision = 2015-04-27
# PIM-MIB
#   revision = 2000-09-28
# CISCO-ETHER-CFM-MIB
#   revision = 2004-12-28
# CISCO-SONET-MIB
#   revision = 2003-03-07
# CISCO-ENTITY-PERFORMANCE-MIB
#   revision = 2010-09-09
# CISCO-IP-URPF-MIB
#   revision = 2011-12-29
# CISCO-IETF-ISIS-MIB
#   revision = 2005-08-16
# CISCO-ENTITY-SENSOR-MIB
#   revision = 2015-01-15
# CISCO-DOT3-OAM-MIB
#   revision = 2006-05-31
# cisco-acl-oper
#   revision = 2015-08-10
# CISCO-MEDIA-GATEWAY-MIB
#   revision = 2009-02-25
# ietf-diffserv-classifier
#   revision = 2015-04-07
#   features = policy-inline-classifier-config
# IANA-ADDRESS-FAMILY-NUMBERS-MIB
#   revision = 2000-09-08
# OSPF-TRAP-MIB
#   revision = 2006-11-10
# CISCO-RTTMON-TC-MIB
#   revision = 2012-05-25
# nvo
#   revision = 2015-06-02
#   deviations = nvo-devs
# MPLS-LDP-STD-MIB
#   revision = 2004-06-03
# CISCO-EMBEDDED-EVENT-MGR-MIB
#   revision = 2006-11-07
# CISCO-DATA-COLLECTION-MIB
#   revision = 2002-10-30
# SNMP-TARGET-MIB
#   revision = 2002-10-14
# PerfHist-TC-MIB
#   revision = 1998-11-07
# NOTIFICATION-LOG-MIB
#   revision = 2000-11-27
# DRAFT-MSDP-MIB
#   revision = 1999-12-16
# DIFFSERV-MIB
#   revision = 2002-02-07
# CISCO-MPLS-LSR-EXT-STD-MIB
#   revision = 2012-04-30
# cisco-bridge-domain
#   revision = 2014-12-01
#   features = parameterized-bridge-domains,configurable-bd-storm-control,configurable-bd-static-mac,configurable-bd-snooping-profiles,configurable-bd-sh-group-number,configurable-bd-mtu,configurable-bd-member-features,configurable-bd-mac-secure,configurable-bd-mac-features,configurable-bd-mac-event-action,configurable-bd-ipsg,configurable-bd-groups,configurable-bd-flooding-mode,configurable-bd-flooding,configurable-bd-dai,clear-bridge-domain
# cisco-pw
#   revision = 2014-12-01
#   features = static-label-direct-config,pw-vccv,pw-tag-impose-vlan-id,pw-status-config,pw-static-oam-config,pw-short-config,pw-sequencing,pw-preferred-path,pw-port-profiles,pw-oam-refresh-config,pw-mac-withdraw-config,pw-load-balancing,pw-ipv6-source,pw-interface,pw-grouping-config,pw-class-tag-rewrite,pw-class-switchover-delay,pw-class-status,pw-class-source-ip,pw-class-flow-setting,preferred-path-peer,predictive-redundancy-config,flow-label-tlv-code17,flow-label-static-config
# cisco-policy-filters
#   revision = 2015-04-27
# CISCO-SESS-BORDER-CTRLR-STATS-MIB
#   revision = 2010-09-15
# cisco-memory-stats
#   revision = 2015-04-09
# cisco-acl
#   revision = 2014-10-10
#   features = tos-support,noncont-port-support,interface-stats-support,hardware-count-support,compression-level-support,acl-common-support,access-list-entry-counter-support,access-list-entry-capture-support,abf-support
# CISCO-FIREWALL-TC
#   revision = 2006-03-03
# CISCO-PING-MIB
#   revision = 2001-08-28
# cisco-virtual-service
#   revision = 2015-04-09
# CISCO-IP-LOCAL-POOL-MIB
#   revision = 2007-11-12
# TRANSPORT-ADDRESS-MIB
#   revision = 2002-11-01
# CISCO-ATM-EXT-MIB
#   revision = 2003-01-06
# ENTITY-STATE-TC-MIB
#   revision = 2005-11-22
# cisco-cfm-stats-dev
#   revision = 2015-05-27
# MPLS-TC-MIB
#   revision = 2001-01-04
# CISCO-MVPN-MIB
#   revision = 2004-02-23
# IF-MIB
#   revision = 2000-06-14
# ietf-inet-types
#   revision = 2013-07-15
# OSPF-MIB
#   revision = 2006-11-10
# govern
#   revision = 2014-07-16
# ietf-routing
#   revision = 2015-05-25
#   deviations = ietf-ipv4-unicast-routing-devs,ietf-ipv6-unicast-routing-devs,ietf-ospf-devs,ietf-routing-devs
#   features = router-id,multiple-ribs
# CISCO-VTP-MIB
#   revision = 2013-10-14
# CISCO-IETF-PW-TC-MIB
#   revision = 2006-07-21
# CISCO-CLASS-BASED-QOS-MIB
#   revision = 2014-01-24
# MPLS-TC-STD-MIB
#   revision = 2004-06-03
# ETHER-WIS
#   revision = 2003-09-19
# ietf-diffserv-action
#   revision = 2015-04-07
#   features = priority-rate-burst-support,hierarchial-policy-support,aqm-red-support
# IEEE8021-TC-MIB
#   revision = 2008-10-15
# tailf-netconf-monitoring
#   revision = 2014-11-13
# CISCO-IETF-PW-TDM-MIB
#   revision = 2006-07-21
# Q-BRIDGE-MIB
#   revision = 2006-01-09
# DIAL-CONTROL-MIB
#   revision = 1996-09-23
# FRAME-RELAY-DTE-MIB
#   revision = 1997-05-01
# CISCO-AAL5-MIB
#   revision = 2003-09-22
# CISCO-ETHERLIKE-EXT-MIB
#   revision = 2010-06-04
# ietf-ospf
#   revision = 2015-03-09
#   deviations = ietf-ospf-devs
#   features = ttl-security,te-rid,router-id,remote-lfa,prefix-suppression,ospfv3-authentication-ipsec,nsr,node-flag,multi-topology,multi-area-adj,mtu-ignore,max-lsa,max-ecmp,lls,lfa,ldp-igp-sync,ldp-igp-autoconfig,interface-inheritance,instance-inheritance,graceful-restart,fast-reroute,demand-circuit,bfd,auto-cost,area-inheritance,admin-control
# common-mpls-static
#   revision = 2015-07-22
#   deviations = common-mpls-static-devs
# TCP-MIB
#   revision = 2005-02-18
# CISCO-PIM-MIB
#   revision = 2000-11-02
# ietf-ip
#   revision = 2014-01-08
#   features = ipv6-privacy-autoconf,ipv4-non-contiguous-netmasks
# ietf-netconf-acm
#   revision = 2012-02-22
# cisco-ospf
#   revision = 2015-05-19
#   features = graceful-shutdown,flood-reduction,database-filter
# CISCO-SUBSCRIBER-SESSION-MIB
#   revision = 2012-08-08
# SNMP-USER-BASED-SM-MIB
#   revision = 2002-10-16
# CISCO-ENTITY-QFP-MIB
#   revision = 2014-06-18
# CISCO-ENTITY-ALARM-MIB
#   revision = 1999-07-06
# CISCO-IGMP-FILTER-MIB
#   revision = 2005-11-29
# CISCO-ST-TC
#   revision = 2012-08-08
# CISCO-VPDN-MGMT-MIB
#   revision = 2009-06-16
# CISCO-IETF-ATM2-PVCTRAP-MIB
#   revision = 1998-02-03
# ietf-key-chain
#   revision = 2015-02-24
#   features = independent-send-accept-lifetime,hex-key-string,accept-tolerance
# CISCO-SMI
#   revision = 2012-08-29
# CISCO-HSRP-EXT-MIB
#   revision = 2010-09-02
# UDP-MIB
#   revision = 2005-05-20
# MPLS-VPN-MIB
#   revision = 2001-10-15
# cdp
#   revision = 2014-01-29
# INET-ADDRESS-MIB
#   revision = 2005-02-04
# IEEE8021-CFM-MIB
#   revision = 2008-10-15
# cisco-bridge-common
#   revision = 2014-09-25
#   features = configurable-bd-mac-limit-notif,configurable-bd-mac-limit-max,configurable-bd-mac-limit-actions,configurable-bd-mac-aging-types,configurable-bd-flooding-control
# TUNNEL-MIB
#   revision = 2005-05-16
# cisco-checkpoint-archive
#   revision = 2015-05-20
# CISCO-IETF-PW-ATM-MIB
#   revision = 2005-04-19
# cisco-process-cpu
#   revision = 2015-04-09
# CISCO-RADIUS-EXT-MIB
#   revision = 2010-05-25
# CISCO-VLAN-IFTABLE-RELATIONSHIP-MIB
#   revision = 2013-07-15
# CISCO-IMAGE-MIB
#   revision = 1995-08-15
# CISCO-NBAR-PROTOCOL-DISCOVERY-MIB
#   revision = 2002-08-16
# CISCO-IETF-PW-ENET-MIB
#   revision = 2002-09-22
# CISCO-SESS-BORDER-CTRLR-CALL-STATS-MIB
#   revision = 2010-09-03
# IPMROUTE-STD-MIB
#   revision = 2000-09-22
# cisco-bgp-state
#   revision = 2015-04-09
# SNMP-FRAMEWORK-MIB
#   revision = 2002-10-14
# INT-SERV-MIB
#   revision = 1997-10-03
# P-BRIDGE-MIB
#   revision = 2006-01-09
# CISCO-IF-EXTENSION-MIB
#   revision = 2013-03-13
# tailf-aaa
#   revision = 2014-08-29
# ATM-TC-MIB
#   revision = 1998-10-19
# CISCO-ENTITY-VENDORTYPE-OID-MIB
#   revision = 2014-12-09
# CISCO-BGP-POLICY-ACCOUNTING-MIB
#   revision = 2002-07-26
# ietf-diffserv-policy
#   revision = 2015-04-07
#   features = policy-template-support,hierarchial-policy-support
# RMON2-MIB
#   revision = 1996-05-27
# BGP4-MIB
#   revision = 1994-05-05
# CISCO-IPMROUTE-MIB
#   revision = 2005-03-07
# CISCO-IETF-PPVPN-MPLS-VPN-MIB
#   revision = 2003-04-17
# CISCO-QOS-PIB-MIB
#   revision = 2007-08-29
# SNMP-COMMUNITY-MIB
#   revision = 2003-08-06
# MPLS-L3VPN-STD-MIB
#   revision = 2006-01-23
# cisco-policy
#   revision = 2015-04-27
# CISCO-ATM-QOS-MIB
#   revision = 2002-06-10
# MPLS-TE-STD-MIB
#   revision = 2004-06-03
# cisco-storm-control
#   revision = 2014-09-25
#   features = configurable-storm-control-actions
# policy-types
#   revision = 2013-10-07
#   features = protocol-name-support,match-wlan-user-priority-support,match-vpls-support,match-vlan-support,match-vlan-inner-support,match-src-mac-support,match-security-group-support,match-qos-group-support,match-prec-support,match-packet-length-support,match-mpls-exp-top-support,match-mpls-exp-imp-support,match-metadata-support,match-ipv6-acl-support,match-ipv6-acl-name-support,match-ipv4-acl-support,match-ipv4-acl-name-support,match-ip-rtp-support,match-input-interface-support,match-fr-dlci-support,match-fr-de-support,match-flow-record-support,match-flow-ip-support,match-dst-mac-support,match-discard-class-support,match-dei-support,match-dei-inner-support,match-cos-support,match-cos-inner-support,match-class-map-support,match-atm-vci-support,match-atm-clp-support,match-application-support
# ENTITY-STATE-MIB
#   revision = 2005-11-22
# ietf-ipv6-unicast-routing
#   revision = 2015-05-25
# CISCO-PTP-MIB
#   revision = 2011-01-28
# CISCO-VLAN-MEMBERSHIP-MIB
#   revision = 2007-12-14
# TOKENRING-MIB
#   revision = 1994-10-23
# NHRP-MIB
#   revision = 1999-08-26
# IP-MIB
#   revision = 2006-02-02
# CISCO-IP-TAP-MIB
#   revision = 2004-03-11
# CISCO-STP-EXTENSIONS-MIB
#   revision = 2013-03-07

# %% [markdown]
# ## Enough!! What About Config?
#
# The ncclient library provides for some simple operations. Let's skip thinking about schemas and stuff like that. Instead let's focus on config and getting end setting it. For that, ncclient provides two methods:
#
# * get_config - takes a target data store and an optional filter
# * edit_config - takes a target data store and an XML document with the edit request

# %% [markdown]
# ### But let's define some utilities first!

# %%
from lxml import etree

def pretty_print(nc_retval):
        print(etree.tostring(etree.fromstring(nc_retval.data_xml), pretty_print=True))

# %% [markdown]
# ### Getting Config
#
# Let's look at some simple requests...

# %%
c = m.get_config(source='running')
pretty_print(c)
# Out:
# <data xmlns="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0">
#   <native xmlns="http://cisco.com/ns/yang/ned/ios">
#     <device-model-version>
#       <major>2</major>
#       <minor>1</minor>
#       <bug-fix>0</bug-fix>
#     </device-model-version>
#     <service>
#       <timestamps>
#         <debug>
#           <datetime>
#             <msec/>
#           </datetime>
#         </debug>
#         <log>
#           <datetime>
#             <msec/>
#           </datetime>
#         </log>
#       </timestamps>
#     </service>
#     <platform>
#       <punt-keepalive>
#         <disable-kernel-core>false</disable-kernel-core>
#       </punt-keepalive>
#     </platform>
#     <enable>
#       <password>
#         <secret>C1sdevops</secret>
#       </password>
#     </enable>
#     <username>
#       <name>admin</name>
#       <password>
#         <encryption>0</encryption>
#         <password>C1sdevops</password>
#       </password>
#     </username>
#     <username>
#       <name>cisco</name>
#       <password>
#         <encryption>0</encryption>
#         <password>C1sdevops</password>
#       </password>
#     </username>
#     <vrf>
#       <definition>
#         <name>Mgmt-vrf</name>
#         <address-family>
#           <ipv4/>
#           <ipv6/>
#         </address-family>
#       </definition>
#     </vrf>
#     <ip>
#       <domain>
#         <name>cisco.com</name>
#       </domain>
#       <forward-protocol>
#         <protocol>nd</protocol>
#       </forward-protocol>
#       <ftp>
#         <source-interface>
#           <GigabitEthernet>0/0</GigabitEthernet>
#         </source-interface>
#       </ftp>
#       <http>
#         <authentication>
#           <local/>
#         </authentication>
#         <server>true</server>
#         <secure-server>true</secure-server>
#       </http>
#       <name-server>64.102.6.247</name-server>
#       <route>
#         <ip-route-interface-forwarding-list>
#           <prefix>0.0.0.0</prefix>
#           <mask>0.0.0.0</mask>
#           <fwd-list>
#             <fwd>172.26.170.1</fwd>
#           </fwd-list>
#         </ip-route-interface-forwarding-list>
#         <vrf>
#           <name>Mgmt-vrf</name>
#           <ip-route-interface-forwarding-list>
#             <prefix>0.0.0.0</prefix>
#             <mask>0.0.0.0</mask>
#             <fwd-list>
#               <fwd>172.26.170.1</fwd>
#             </fwd-list>
#           </ip-route-interface-forwarding-list>
#         </vrf>
#       </route>
#       <routing/>
#       <ssh>
#         <source-interface>GigabitEthernet0/0</source-interface>
#       </ssh>
#       <tftp>
#         <source-interface>
#           <GigabitEthernet>0/0</GigabitEthernet>
#         </source-interface>
#       </tftp>
#       <access-list>
#         <extended>
#           <name>AutoQos-4.0-wlan-Acl-Bulk-Data</name>
#           <access-list-seq-rule>
#             <sequence>10</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>22</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>20</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>465</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>30</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>143</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>40</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>993</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>50</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>995</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>60</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>1914</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>70</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>ftp</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>80</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>ftp-data</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>90</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>smtp</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>100</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>pop3</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#         </extended>
#         <extended>
#           <name>AutoQos-4.0-wlan-Acl-MultiEnhanced-Conf</name>
#           <access-list-seq-rule>
#             <sequence>10</sequence>
#             <permit>
#               <acl-protocol>
#                 <udp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <port-match-oper>
#                         <range>
#                           <port-operand1>
#                             <port-operand>16384</port-operand>
#                             <udp-port-operand>32767</udp-port-operand>
#                           </port-operand1>
#                         </range>
#                       </port-match-oper>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </udp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>20</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <range>
#                           <port-operand1>
#                             <port-operand>50000</port-operand>
#                             <udp-port-operand>59999</udp-port-operand>
#                           </port-operand1>
#                         </range>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#         </extended>
#         <extended>
#           <name>AutoQos-4.0-wlan-Acl-Scavanger</name>
#           <access-list-seq-rule>
#             <sequence>10</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <range>
#                           <port-operand1>
#                             <port-operand>2300</port-operand>
#                             <udp-port-operand>2400</udp-port-operand>
#                           </port-operand1>
#                         </range>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>20</sequence>
#             <permit>
#               <acl-protocol>
#                 <udp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <port-match-oper>
#                         <range>
#                           <port-operand1>
#                             <port-operand>2300</port-operand>
#                             <udp-port-operand>2400</udp-port-operand>
#                           </port-operand1>
#                         </range>
#                       </port-match-oper>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </udp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>30</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <range>
#                           <port-operand1>
#                             <port-operand>6881</port-operand>
#                             <udp-port-operand>6999</udp-port-operand>
#                           </port-operand1>
#                         </range>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>40</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <range>
#                           <port-operand1>
#                             <port-operand>28800</port-operand>
#                             <udp-port-operand>29100</udp-port-operand>
#                           </port-operand1>
#                         </range>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>50</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>1214</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>60</sequence>
#             <permit>
#               <acl-protocol>
#                 <udp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <port-match-oper>
#                         <eq>
#                           <port-operand>1214</port-operand>
#                         </eq>
#                       </port-match-oper>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </udp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>70</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>3689</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>80</sequence>
#             <permit>
#               <acl-protocol>
#                 <udp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <port-match-oper>
#                         <eq>
#                           <port-operand>3689</port-operand>
#                         </eq>
#                       </port-match-oper>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </udp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>90</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>11999</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#         </extended>
#         <extended>
#           <name>AutoQos-4.0-wlan-Acl-Signaling</name>
#           <access-list-seq-rule>
#             <sequence>10</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <range>
#                           <port-operand1>
#                             <port-operand>2000</port-operand>
#                             <udp-port-operand>2002</udp-port-operand>
#                           </port-operand1>
#                         </range>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>20</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <range>
#                           <port-operand1>
#                             <port-operand>5060</port-operand>
#                             <udp-port-operand>5061</udp-port-operand>
#                           </port-operand1>
#                         </range>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>30</sequence>
#             <permit>
#               <acl-protocol>
#                 <udp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <port-match-oper>
#                         <range>
#                           <port-operand1>
#                             <port-operand>5060</port-operand>
#                             <udp-port-operand>5061</udp-port-operand>
#                           </port-operand1>
#                         </range>
#                       </port-match-oper>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </udp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#         </extended>
#         <extended>
#           <name>AutoQos-4.0-wlan-Acl-Transactional-Data</name>
#           <access-list-seq-rule>
#             <sequence>10</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>443</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>20</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>1521</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>30</sequence>
#             <permit>
#               <acl-protocol>
#                 <udp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <port-match-oper>
#                         <eq>
#                           <port-operand>1521</port-operand>
#                         </eq>
#                       </port-match-oper>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </udp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>40</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>1526</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>50</sequence>
#             <permit>
#               <acl-protocol>
#                 <udp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <port-match-oper>
#                         <eq>
#                           <port-operand>1526</port-operand>
#                         </eq>
#                       </port-match-oper>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </udp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>60</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>1575</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>70</sequence>
#             <permit>
#               <acl-protocol>
#                 <udp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <port-match-oper>
#                         <eq>
#                           <port-operand>1575</port-operand>
#                         </eq>
#                       </port-match-oper>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </udp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>80</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>1630</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>90</sequence>
#             <permit>
#               <acl-protocol>
#                 <udp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <port-match-oper>
#                         <eq>
#                           <port-operand>1630</port-operand>
#                         </eq>
#                       </port-match-oper>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </udp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>100</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>1527</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>110</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>6200</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>120</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>3389</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>130</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>5985</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>140</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>8080</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#         </extended>
#         <extended>
#           <name>CISCO-CWA-URL-REDIRECT-ACL</name>
#           <access-list-seq-rule>
#             <sequence>100</sequence>
#             <deny>
#               <acl-protocol>
#                 <udp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <port-match-oper>
#                         <eq>
#                           <port-operand>domain</port-operand>
#                         </eq>
#                       </port-match-oper>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </udp>
#               </acl-protocol>
#             </deny>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>101</sequence>
#             <deny>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>domain</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </deny>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>102</sequence>
#             <deny>
#               <acl-protocol>
#                 <udp>
#                   <source-destination-match>
#                     <any/>
#                     <src-udp-eq>bootps</src-udp-eq>
#                     <dst-any/>
#                   </source-destination-match>
#                 </udp>
#               </acl-protocol>
#             </deny>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>103</sequence>
#             <deny>
#               <acl-protocol>
#                 <udp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <port-match-oper>
#                         <eq>
#                           <udp-port-operand>bootpc</udp-port-operand>
#                         </eq>
#                       </port-match-oper>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </udp>
#               </acl-protocol>
#             </deny>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>104</sequence>
#             <deny>
#               <acl-protocol>
#                 <udp>
#                   <source-destination-match>
#                     <any/>
#                     <src-udp-eq>bootpc</src-udp-eq>
#                     <dst-any/>
#                   </source-destination-match>
#                 </udp>
#               </acl-protocol>
#             </deny>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>105</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>www</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#         </extended>
#         <extended>
#           <name>IP-Adm-V4-Int-ACL-global</name>
#           <access-list-seq-rule>
#             <sequence>10</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>www</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>20</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>443</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#         </extended>
#         <extended>
#           <name>preauth_v4</name>
#           <access-list-seq-rule>
#             <sequence>10</sequence>
#             <permit>
#               <acl-protocol>
#                 <udp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <port-match-oper>
#                         <eq>
#                           <port-operand>domain</port-operand>
#                         </eq>
#                       </port-match-oper>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </udp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>20</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>domain</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>30</sequence>
#             <permit>
#               <acl-protocol>
#                 <udp>
#                   <source-destination-match>
#                     <any/>
#                     <src-udp-eq>bootps</src-udp-eq>
#                     <dst-any/>
#                   </source-destination-match>
#                 </udp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>40</sequence>
#             <permit>
#               <acl-protocol>
#                 <udp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <port-match-oper>
#                         <eq>
#                           <udp-port-operand>bootpc</udp-port-operand>
#                         </eq>
#                       </port-match-oper>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </udp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>50</sequence>
#             <permit>
#               <acl-protocol>
#                 <udp>
#                   <source-destination-match>
#                     <any/>
#                     <src-udp-eq>bootpc</src-udp-eq>
#                     <dst-any/>
#                   </source-destination-match>
#                 </udp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>60</sequence>
#             <deny>
#               <acl-protocol>
#                 <ip>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                   </source-destination-match>
#                 </ip>
#               </acl-protocol>
#             </deny>
#           </access-list-seq-rule>
#         </extended>
#       </access-list>
#     </ip>
#     <vlan>
#       <vlan-list>
#         <id>10</id>
#       </vlan-list>
#     </vlan>
#     <interface>
#       <GigabitEthernet>
#         <name>0/0</name>
#         <negotiation>
#           <auto>true</auto>
#         </negotiation>
#         <description>boom</description>
#         <vrf>
#           <forwarding>Mgmt-vrf</forwarding>
#         </vrf>
#         <ip>
#           <address>
#             <primary>
#               <address>172.26.170.252</address>
#               <mask>255.255.254.0</mask>
#             </primary>
#           </address>
#         </ip>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/1</name>
#         <description>boom</description>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/10</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/11</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/12</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/13</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/14</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/15</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/16</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/17</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/18</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/19</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/2</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/20</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/21</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/22</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/23</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/24</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/25</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/26</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/27</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/28</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/29</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/3</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/30</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/31</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/32</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/33</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/34</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/35</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/36</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/37</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/38</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/39</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/4</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/40</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/41</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/42</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/43</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/44</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/45</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/46</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/47</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/48</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/5</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/6</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/7</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/8</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/9</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/1/1</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/1/2</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/1/3</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/1/4</name>
#       </GigabitEthernet>
#       <TenGigabitEthernet>
#         <name>1/1/1</name>
#       </TenGigabitEthernet>
#       <TenGigabitEthernet>
#         <name>1/1/2</name>
#       </TenGigabitEthernet>
#       <TenGigabitEthernet>
#         <name>1/1/3</name>
#       </TenGigabitEthernet>
#       <TenGigabitEthernet>
#         <name>1/1/4</name>
#       </TenGigabitEthernet>
#       <Vlan>
#         <name>1</name>
#         <ip>
#           <no-address>
#             <address>false</address>
#           </no-address>
#         </ip>
#         <shutdown/>
#       </Vlan>
#     </interface>
#     <diagnostic>
#       <bootup>
#         <level>minimal</level>
#       </bootup>
#     </diagnostic>
#     <switch>
#       <number>1</number>
#       <provision>ws-c3850-48u</provision>
#     </switch>
#     <class-map>
#       <name>non-client-nrt-class</name>
#       <prematch>match-any</prematch>
#     </class-map>
#     <class-map>
#       <name>system-cpp-default</name>
#       <prematch>match-any</prematch>
#       <description>DHCP snooping, show forward and rest of traffic</description>
#     </class-map>
#     <class-map>
#       <name>system-cpp-police-control-low-priority</name>
#       <prematch>match-any</prematch>
#       <description>ICMP redirect and general punt</description>
#     </class-map>
#     <class-map>
#       <name>system-cpp-police-data</name>
#       <prematch>match-any</prematch>
#       <description>ICMP_GEN and BROADCAST</description>
#     </class-map>
#     <class-map>
#       <name>system-cpp-police-dot1x-auth</name>
#       <prematch>match-any</prematch>
#       <description>DOT1X Auth</description>
#     </class-map>
#     <class-map>
#       <name>system-cpp-police-forus</name>
#       <prematch>match-any</prematch>
#       <description>Forus Address resolution and Forus traffic</description>
#     </class-map>
#     <class-map>
#       <name>system-cpp-police-l2-control</name>
#       <prematch>match-any</prematch>
#       <description>L2 control</description>
#     </class-map>
#     <class-map>
#       <name>system-cpp-police-multicast</name>
#       <prematch>match-any</prematch>
#       <description>Transit Traffic and MCAST Data</description>
#     </class-map>
#     <class-map>
#       <name>system-cpp-police-multicast-end-station</name>
#       <prematch>match-any</prematch>
#       <description>MCAST END STATION</description>
#     </class-map>
#     <class-map>
#       <name>system-cpp-police-protocol-snooping</name>
#       <prematch>match-any</prematch>
#       <description>Protocol snooping</description>
#     </class-map>
#     <class-map>
#       <name>system-cpp-police-punt-webauth</name>
#       <prematch>match-any</prematch>
#       <description>Punt Webauth</description>
#     </class-map>
#     <class-map>
#       <name>system-cpp-police-routing-control</name>
#       <prematch>match-any</prematch>
#       <description>Routing control</description>
#     </class-map>
#     <class-map>
#       <name>system-cpp-police-sw-forward</name>
#       <prematch>match-any</prematch>
#       <description>Sw forwarding, SGT Cache Full, LOGGING</description>
#     </class-map>
#     <class-map>
#       <name>system-cpp-police-sys-data</name>
#       <prematch>match-any</prematch>
#       <description>Learning cache ovfl, Crypto Control, Exception, EGR Exception, NFL SAMPLED DATA, Gold Pkt, RPF Failed</description>
#     </class-map>
#     <class-map>
#       <name>system-cpp-police-topology-control</name>
#       <prematch>match-any</prematch>
#       <description>Topology control</description>
#     </class-map>
#     <class-map>
#       <name>system-cpp-police-wireless-priority1</name>
#       <prematch>match-any</prematch>
#       <description>Wireless priority 1</description>
#     </class-map>
#     <class-map>
#       <name>system-cpp-police-wireless-priority2</name>
#       <prematch>match-any</prematch>
#       <description>Wireless priority 2</description>
#     </class-map>
#     <class-map>
#       <name>system-cpp-police-wireless-priority3-4-5</name>
#       <prematch>match-any</prematch>
#       <description>Wireless priority 3,4 and 5</description>
#     </class-map>
#     <policy-map>
#       <name>c-C_C</name>
#       <class>
#         <name>class-default</name>
#         <action-list>
#           <action-type>set</action-type>
#           <set>
#             <dscp>
#               <dscp-val>default</dscp-val>
#             </dscp>
#           </set>
#         </action-list>
#       </class>
#     </policy-map>
#     <policy-map>
#       <name>port_child_policy</name>
#       <class>
#         <name>non-client-nrt-class</name>
#         <action-list>
#           <action-type>bandwidth</action-type>
#           <bandwidth>
#             <remaining>
#               <ratio>10</ratio>
#             </remaining>
#           </bandwidth>
#         </action-list>
#       </class>
# ...
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/2</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/20</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/21</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/22</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/23</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/24</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/25</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/26</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/27</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/28</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/29</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/3</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/30</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/31</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/32</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/33</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/34</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/35</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/36</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/37</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/38</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/39</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/4</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/40</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/41</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/42</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/43</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/44</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/45</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/46</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/47</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/48</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/5</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/6</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/7</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/8</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/9</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/1/1</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/1/2</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/1/3</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/1/4</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>TenGigabitEthernet1/1/1</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>TenGigabitEthernet1/1/2</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>TenGigabitEthernet1/1/3</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>TenGigabitEthernet1/1/4</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#   </interfaces>
#   <routing xmlns="urn:ietf:params:xml:ns:yang:ietf-routing">
#     <routing-instance>
#       <name>Mgmt-vrf</name>
#       <interfaces>
#         <interface>GigabitEthernet0/0</interface>
#       </interfaces>
#       <routing-protocols>
#         <routing-protocol>
#           <type>static</type>
#           <name>1</name>
#           <static-routes>
#             <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ipv4-unicast-routing">
#               <route>
#                 <destination-prefix>0.0.0.0/0</destination-prefix>
#                 <next-hop>
#                   <next-hop-address>172.26.170.1</next-hop-address>
#                 </next-hop>
#               </route>
#             </ipv4>
#           </static-routes>
#         </routing-protocol>
#       </routing-protocols>
#     </routing-instance>
#     <routing-instance>
#       <name>default</name>
#       <description>default-vrf [read-only]</description>
#       <interfaces/>
#       <routing-protocols>
#         <routing-protocol>
#           <type>static</type>
#           <name>1</name>
#           <static-routes>
#             <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ipv4-unicast-routing">
#               <route>
#                 <destination-prefix>0.0.0.0/0</destination-prefix>
#                 <next-hop>
#                   <next-hop-address>172.26.170.1</next-hop-address>
#                 </next-hop>
#               </route>
#             </ipv4>
#           </static-routes>
#         </routing-protocol>
#       </routing-protocols>
#     </routing-instance>
#   </routing>
# </data>

# %% [markdown]
# Now let's add in a simple filter (this example only works on IOS-XE 16.3.1 and later):

# %%
filter = '''
<netconf-yang/>
'''
c = m.get_config(source='running', filter=('subtree', filter))
pretty_print(c)
# Out:
# <data xmlns="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0"/>

# %% [markdown]
# ### Retieve Route Data

# %%
filter = '''
<native>
  <ip>
    <route/>
  </ip>
</native>
'''
c = m.get_config(source='running', filter=('subtree', filter))
pretty_print(c)
# Out:
# <data xmlns="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0">
#   <native xmlns="http://cisco.com/ns/yang/ned/ios">
#     <ip>
#       <route>
#         <ip-route-interface-forwarding-list>
#           <prefix>0.0.0.0</prefix>
#           <mask>0.0.0.0</mask>
#           <fwd-list>
#             <fwd>172.26.170.1</fwd>
#           </fwd-list>
#         </ip-route-interface-forwarding-list>
#         <vrf>
#           <name>Mgmt-vrf</name>
#           <ip-route-interface-forwarding-list>
#             <prefix>0.0.0.0</prefix>
#             <mask>0.0.0.0</mask>
#             <fwd-list>
#               <fwd>172.26.170.1</fwd>
#             </fwd-list>
#           </ip-route-interface-forwarding-list>
#         </vrf>
#       </route>
#     </ip>
#   </native>
# </data>

# %% [markdown]
# ### Retrieve All BGP Data
#
# Now let's look at the BGP native model:

# %%
filter = '''
<native>
  <router>
    <bgp/>
  </router>
</native>
'''
c = m.get_config(source='running', filter=('subtree', filter))
pretty_print(c)
# Out:
# <data xmlns="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0">
#   <native xmlns="urn:ios">
#     <router>
#       <bgp>
#         <as-no>1</as-no>
#         <bgp>
#           <router-id>192.168.0.7</router-id>
#           <log-neighbor-changes/>
#         </bgp>
#         <maximum-paths>
#           <max-path>
#             <max>1</max>
#           </max-path>
#           <external-rtfilter>
#             <max>1</max>
#           </external-rtfilter>
#         </maximum-paths>
#         <neighbor>
#           <id>2001:DB8:B:0:1::3</id>
#           <remote-as>1</remote-as>
#           <activate/>
#           <description>iBGP peer iosv-1</description>
#           <password>
#             <enctype>0</enctype>
#           </password>
#           <update-source>
#             <Loopback>0</Loopback>
#           </update-source>
#         </neighbor>
#         <neighbor>
#           <id>2001:DB8:B:0:1::4</id>
#           <remote-as>1</remote-as>
#           <activate/>
#           <description>iBGP peer iosv-2</description>
#           <password>
#             <enctype>0</enctype>
#           </password>
#           <update-source>
#             <Loopback>0</Loopback>
#           </update-source>
#         </neighbor>
#         <neighbor>
#           <id>2001:DB8:B:0:1::5</id>
#           <remote-as>1</remote-as>
#           <activate/>
#           <description>iBGP peer iosv-3</description>
#           <password>
#             <enctype>0</enctype>
#           </password>
#           <update-source>
#             <Loopback>0</Loopback>
#           </update-source>
#         </neighbor>
#         <neighbor>
#           <id>2001:DB8:B:0:1::6</id>
#           <remote-as>1</remote-as>
#           <activate/>
#           <description>iBGP peer iosxrv-1</description>
#           <password>
#             <enctype>0</enctype>
#           </password>
#           <update-source>
#             <Loopback>0</Loopback>
#           </update-source>
#         </neighbor>
#         <neighbor>
#           <id>2001:DB8:B:0:1::7</id>
#           <remote-as>1</remote-as>
#           <activate/>
#           <description>iBGP peer iosxrv-2</description>
#           <password>
#             <enctype>0</enctype>
#           </password>
#           <update-source>
#             <Loopback>0</Loopback>
#           </update-source>
#         </neighbor>
#         <neighbor>
#           <id>2001:DB8:B:0:1::8</id>
#           <remote-as>1</remote-as>
#           <activate/>
#           <description>iBGP peer iosxrv-3</description>
#           <password>
#             <enctype>0</enctype>
#           </password>
#           <update-source>
#             <Loopback>0</Loopback>
#           </update-source>
#         </neighbor>
#         <neighbor>
#           <id>192.168.0.1</id>
#           <remote-as>1</remote-as>
#           <description>iBGP peer iosv-1</description>
#           <password>
#             <enctype>0</enctype>
#           </password>
#           <update-source>
#             <Loopback>0</Loopback>
#           </update-source>
#         </neighbor>
#         <neighbor>
#           <id>192.168.0.2</id>
#           <remote-as>1</remote-as>
#           <description>iBGP peer iosxrv-1</description>
#           <password>
#             <enctype>0</enctype>
#           </password>
#           <update-source>
#             <Loopback>0</Loopback>
#           </update-source>
#         </neighbor>
#         <neighbor>
#           <id>192.168.0.3</id>
#           <remote-as>1</remote-as>
#           <description>iBGP peer iosxrv-2</description>
#           <password>
#             <enctype>0</enctype>
#           </password>
#           <update-source>
#             <Loopback>0</Loopback>
#           </update-source>
#         </neighbor>
#         <neighbor>
#           <id>192.168.0.4</id>
#           <remote-as>1</remote-as>
#           <description>iBGP peer iosv-2</description>
#           <password>
#             <enctype>0</enctype>
#           </password>
#           <update-source>
#             <Loopback>0</Loopback>
#           </update-source>
#         </neighbor>
#         <neighbor>
#           <id>192.168.0.5</id>
#           <remote-as>1</remote-as>
#           <description>iBGP peer iosxrv-3</description>
#           <password>
#             <enctype>0</enctype>
#           </password>
#           <update-source>
#             <Loopback>0</Loopback>
#           </update-source>
#         </neighbor>
#         <neighbor>
#           <id>192.168.0.6</id>
#           <remote-as>1</remote-as>
#           <description>iBGP peer iosv-3</description>
#           <password>
#             <enctype>0</enctype>
#           </password>
#           <update-source>
#             <Loopback>0</Loopback>
#           </update-source>
#         </neighbor>
#         <address-family>
#           <no-vrf>
#             <ipv4>
#               <unicast-multicast>unicast</unicast-multicast>
#               <maximum-paths>
#                 <max-path>
#                   <max>1</max>
#                 </max-path>
#                 <external-rtfilter>
#                   <max>1</max>
#                 </external-rtfilter>
#               </maximum-paths>
#               <neighbor>
#                 <id>192.168.0.1</id>
#                 <activate/>
#                 <password>
#                   <enctype>0</enctype>
#                 </password>
#               </neighbor>
#               <neighbor>
#                 <id>192.168.0.2</id>
#                 <activate/>
#                 <password>
#                   <enctype>0</enctype>
#                 </password>
#               </neighbor>
#               <neighbor>
#                 <id>192.168.0.3</id>
#                 <activate/>
#                 <password>
#                   <enctype>0</enctype>
#                 </password>
#               </neighbor>
#               <neighbor>
#                 <id>192.168.0.4</id>
#                 <activate/>
#                 <password>
#                   <enctype>0</enctype>
#                 </password>
#               </neighbor>
#               <neighbor>
#                 <id>192.168.0.5</id>
#                 <activate/>
#                 <password>
#                   <enctype>0</enctype>
#                 </password>
#               </neighbor>
#               <neighbor>
#                 <id>192.168.0.6</id>
#                 <activate/>
#                 <password>
#                   <enctype>0</enctype>
#                 </password>
#               </neighbor>
#               <network>
#                 <number>192.168.0.7</number>
#                 <mask>255.255.255.255</mask>
#               </network>
#             </ipv4>
#           </no-vrf>
#           <ipv6>
#             <unicast-multicast>unicast</unicast-multicast>
#             <maximum-paths>
#               <max-path>
#                 <max>1</max>
#               </max-path>
#               <external-rtfilter>
#                 <max>1</max>
#               </external-rtfilter>
#             </maximum-paths>
#           </ipv6>
#         </address-family>
#       </bgp>
#     </router>
#   </native>
# </data>

# %% [markdown]
# ### Look At A Specific BGP Neighbor
#
# And can we look at a specific neighbor only? Say the one with id (address) '192.168.0.1'?

# %%
filter = '''
<native>
  <router>
    <bgp>
      <as-no>1</as-no>
      <neighbor>
        <id>192.168.0.1</id>
      </neighbor>
    </bgp>
  </router>
</native>
'''
c = m.get_config(source='running', filter=('subtree', filter))
pretty_print(c)
# Out:
# <data xmlns="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0">
#   <native xmlns="urn:ios">
#     <router>
#       <bgp>
#         <as-no>1</as-no>
#         <neighbor>
#           <id>192.168.0.1</id>
#           <remote-as>1</remote-as>
#           <description>iBGP peer iosv-1</description>
#           <password>
#             <enctype>0</enctype>
#           </password>
#           <update-source>
#             <Loopback>0</Loopback>
#           </update-source>
#         </neighbor>
#       </bgp>
#     </router>
#   </native>
# </data>

# %% [markdown]
# ### Create New BGP Neighbor
#
# Ok, so, yes we can get a specific neighbor. Now, can we create a new neighbor? Let's create one with an id of '192.168.1.1', with a remote-as of 666.

# %%
from ncclient.operations import TimeoutExpiredError

edit_data = '''
<config>
  <native xmlns="urn:ios">
    <router>
      <bgp>
        <as-no>1</as-no>
        <neighbor nc:operation="create">
          <id>192.168.1.1</id>
          <remote-as>666</remote-as>
          <description nc:operation>a new neighbor</description>
        </neighbor>
      </bgp>
    </router>
  </native>
</config>
'''

try:
    edit_reply = m.edit_config(edit_data, target='running', format='xml')
except TimeoutExpiredError as e:
    print("Operation timeout!")
except Exception as e:
    print("severity={}, tag={}".format(e.severity, e.tag))
    print(e)

# %% [markdown]
# Now let's pull back that neighbor:

# %%
filter = '''
<native>
  <router>
    <bgp>
      <as-no>1</as-no>
      <neighbor>
        <id>192.168.1.1</id>
      </neighbor>
    </bgp>
  </router>
</native>
'''
c = m.get_config(source='running', filter=('subtree', filter))
pretty_print(c)
# Out:
# <data xmlns="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0">
#   <native xmlns="urn:ios">
#     <router>
#       <bgp>
#         <as-no>1</as-no>
#         <neighbor>
#           <id>192.168.1.1</id>
#           <remote-as>666</remote-as>
#           <description>modified description</description>
#           <password>
#             <enctype>0</enctype>
#           </password>
#           <update-source>
#             <Loopback>0</Loopback>
#           </update-source>
#         </neighbor>
#       </bgp>
#     </router>
#   </native>
# </data>

# %% [markdown]
# ### Modify The BGP Neighbor Description
#
# Can modify something in the neighbor we just created? Let's keep it simple and modify the description:

# %%
from ncclient.operations import TimeoutExpiredError

edit_data = '''
<config>
  <native xmlns="urn:ios">
    <router>
      <bgp>
        <as-no>1</as-no>
        <neighbor>
          <id>192.168.1.1</id>
          <description nc:operation="merge">modified description</description>
        </neighbor>
      </bgp>
    </router>
  </native>
</config>
'''

try:
    edit_reply = m.edit_config(edit_data, target='running', format='xml')
except TimeoutExpiredError as e:
    print("Operation timeout!")
except Exception as e:
    print("severity={}, tag={}".format(e.severity, e.tag))
    print(e)

# %% [markdown]
# ## Other Stuff

# %% [markdown]
# Get interface data from native model:

# %%
filter = '''
<native>
  <interface/>
</native>
'''
c = m.get_config(source='running', filter=('subtree', filter))
pretty_print(c)
# Out:
# <data xmlns="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0">
#   <native xmlns="urn:ios">
#     <interface>
#       <GigabitEthernet>
#         <name>1</name>
#         <negotiation>
#           <auto>true</auto>
#         </negotiation>
#         <description>OOB Management</description>
#         <cdp>
#           <enable>true</enable>
#         </cdp>
#         <ip>
#           <address>
#             <primary>
#               <address>172.16.1.158</address>
#               <mask>255.255.255.0</mask>
#             </primary>
#           </address>
#         </ip>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>2</name>
#         <negotiation>
#           <auto>true</auto>
#         </negotiation>
#         <description>to iosv-1</description>
#         <cdp>
#           <enable>true</enable>
#         </cdp>
#         <ip>
#           <address>
#             <primary>
#               <address>10.0.0.21</address>
#               <mask>255.255.255.252</mask>
#             </primary>
#           </address>
#           <ospf>
#             <cost>1</cost>
#           </ospf>
#         </ip>
#         <ipv6>
#           <address>
#             <prefix-list>
#               <prefix>2001:DB8:A:0:1:1:0:17/126</prefix>
#             </prefix-list>
#           </address>
#           <ospf>
#             <process>
#               <id>1</id>
#               <area>0</area>
#             </process>
#             <cost>1</cost>
#           </ospf>
#         </ipv6>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>3</name>
#         <negotiation>
#           <auto>true</auto>
#         </negotiation>
#         <description>to iosxrv-3</description>
#         <cdp>
#           <enable>true</enable>
#         </cdp>
#         <ip>
#           <address>
#             <primary>
#               <address>10.0.0.29</address>
#               <mask>255.255.255.252</mask>
#             </primary>
#           </address>
#           <ospf>
#             <cost>1</cost>
#           </ospf>
#         </ip>
#         <ipv6>
#           <address>
#             <prefix-list>
#               <prefix>2001:DB8:A:0:1:1:0:1F/126</prefix>
#             </prefix-list>
#           </address>
#           <ospf>
#             <process>
#               <id>1</id>
#               <area>0</area>
#             </process>
#             <cost>1</cost>
#           </ospf>
#         </ipv6>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>4</name>
#         <negotiation>
#           <auto>true</auto>
#         </negotiation>
#         <description>to iosv-2</description>
#         <cdp>
#           <enable>true</enable>
#         </cdp>
#         <ip>
#           <address>
#             <primary>
#               <address>10.0.0.25</address>
#               <mask>255.255.255.252</mask>
#             </primary>
#           </address>
#           <ospf>
#             <cost>1</cost>
#           </ospf>
#         </ip>
#         <ipv6>
#           <address>
#             <prefix-list>
#               <prefix>2001:DB8:A:0:1:1:0:1B/126</prefix>
#             </prefix-list>
#           </address>
#           <ospf>
#             <process>
#               <id>1</id>
#               <area>0</area>
#             </process>
#             <cost>1</cost>
#           </ospf>
#         </ipv6>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>5</name>
#         <negotiation>
#           <auto>true</auto>
#         </negotiation>
#         <description>to iosv-3</description>
#         <cdp>
#           <enable>true</enable>
#         </cdp>
#         <ip>
#           <address>
#             <primary>
#               <address>10.0.0.33</address>
#               <mask>255.255.255.252</mask>
#             </primary>
#           </address>
#           <ospf>
#             <cost>1</cost>
#           </ospf>
#         </ip>
#         <ipv6>
#           <address>
#             <prefix-list>
#               <prefix>2001:DB8:A:0:1:1:0:23/126</prefix>
#             </prefix-list>
#           </address>
#           <ospf>
#             <process>
#               <id>1</id>
#               <area>0</area>
#             </process>
#             <cost>1</cost>
#           </ospf>
#         </ipv6>
#       </GigabitEthernet>
#       <Loopback>
#         <name>0</name>
#         <description>Loopback</description>
#         <ip>
#           <address>
#             <primary>
#               <address>192.168.0.7</address>
#               <mask>255.255.255.255</mask>
#             </primary>
#           </address>
#         </ip>
#         <ipv6>
#           <address>
#             <prefix-list>
#               <prefix>2001:DB8:B:0:1::2/128</prefix>
#             </prefix-list>
#           </address>
#           <ospf>
#             <process>
#               <id>1</id>
#               <area>0</area>
#             </process>
#             <cost>1</cost>
#           </ospf>
#         </ipv6>
#       </Loopback>
#       <VirtualPortGroup>
#         <name>0</name>
#         <ip>
#           <unnumbered>GigabitEthernet1</unnumbered>
#         </ip>
#         <mop>
#           <enabled>false</enabled>
#         </mop>
#       </VirtualPortGroup>
#     </interface>
#   </native>
# </data>

# %%
filter = '''
<native>
  <interface>
    <GigabitEthernet>
      <name/>
      <ip/>
    </GigabitEthernet>
  </interface>
</native>
'''
c = m.get_config(source='running', filter=('subtree', filter))
pretty_print(c)
# Out:
# <data xmlns="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0">
#   <native xmlns="urn:ios">
#     <interface>
#       <GigabitEthernet>
#         <name>1</name>
#         <ip>
#           <address>
#             <primary>
#               <address>172.16.1.158</address>
#               <mask>255.255.255.0</mask>
#             </primary>
#           </address>
#         </ip>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>2</name>
#         <ip>
#           <address>
#             <primary>
#               <address>10.0.0.21</address>
#               <mask>255.255.255.252</mask>
#             </primary>
#           </address>
#           <ospf>
#             <cost>1</cost>
#           </ospf>
#         </ip>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>3</name>
#         <ip>
#           <address>
#             <primary>
#               <address>10.0.0.29</address>
#               <mask>255.255.255.252</mask>
#             </primary>
#           </address>
#           <ospf>
#             <cost>1</cost>
#           </ospf>
#         </ip>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>4</name>
#         <ip>
#           <address>
#             <primary>
#               <address>10.0.0.25</address>
#               <mask>255.255.255.252</mask>
#             </primary>
#           </address>
#           <ospf>
#             <cost>1</cost>
#           </ospf>
#         </ip>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>5</name>
#         <ip>
#           <address>
#             <primary>
#               <address>10.0.0.33</address>
#               <mask>255.255.255.252</mask>
#             </primary>
#           </address>
#           <ospf>
#             <cost>1</cost>
#           </ospf>
#         </ip>
#       </GigabitEthernet>
#     </interface>
#   </native>
# </data>

# %%
filter = '''
<native>
  <interface>
    <GigabitEthernet>
      <name>1/0/1</name>
    </GigabitEthernet>
  </interface>
</native>
'''
c = m.get_config(source='running', filter=('subtree', filter))
pretty_print(c)
# Out:
# <data xmlns="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0">
#   <native xmlns="http://cisco.com/ns/yang/ned/ios">
#     <interface>
#       <GigabitEthernet>
#         <name>1/0/1</name>
#         <switchport-conf>
#           <switchport>false</switchport>
#         </switchport-conf>
#         <description>boom</description>
#         <ip>
#           <address>
#             <primary>
#               <address>1.1.1.1</address>
#               <mask>255.255.254.0</mask>
#             </primary>
#           </address>
#         </ip>
#       </GigabitEthernet>
#     </interface>
#   </native>
# </data>

# %% [markdown]
# Get interfaces from IETF model:

# %%
filter = '''
<interfaces xmlns="urn:ietf:params:xml:ns:yang:ietf-interfaces"/>
'''
c = m.get_config(source='running', filter=('subtree', filter))
pretty_print(c)
# Out:
# <data xmlns="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0">
#   <interfaces xmlns="urn:ietf:params:xml:ns:yang:ietf-interfaces">
#     <interface>
#       <name>GigabitEthernet1</name>
#       <description>OOB Management</description>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip">
#         <address>
#           <ip>172.16.1.158</ip>
#           <netmask>255.255.255.0</netmask>
#         </address>
#       </ipv4>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet2</name>
#       <description>to iosv-1</description>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip">
#         <address>
#           <ip>10.0.0.21</ip>
#           <netmask>255.255.255.252</netmask>
#         </address>
#       </ipv4>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip">
#         <address>
#           <ip>2001:db8:a:0:1:1:0:17</ip>
#           <prefix-length>126</prefix-length>
#         </address>
#       </ipv6>
#     </interface>
#     <interface>
#       <name>GigabitEthernet3</name>
#       <description>to iosxrv-3</description>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip">
#         <address>
#           <ip>10.0.0.29</ip>
#           <netmask>255.255.255.252</netmask>
#         </address>
#       </ipv4>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip">
#         <address>
#           <ip>2001:db8:a:0:1:1:0:1f</ip>
#           <prefix-length>126</prefix-length>
#         </address>
#       </ipv6>
#     </interface>
#     <interface>
#       <name>GigabitEthernet4</name>
#       <description>to iosv-2</description>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip">
#         <address>
#           <ip>10.0.0.25</ip>
#           <netmask>255.255.255.252</netmask>
#         </address>
#       </ipv4>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip">
#         <address>
#           <ip>2001:db8:a:0:1:1:0:1b</ip>
#           <prefix-length>126</prefix-length>
#         </address>
#       </ipv6>
#     </interface>
#     <interface>
#       <name>GigabitEthernet5</name>
#       <description>to iosv-3</description>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip">
#         <address>
#           <ip>10.0.0.33</ip>
#           <netmask>255.255.255.252</netmask>
#         </address>
#       </ipv4>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip">
#         <address>
#           <ip>2001:db8:a:0:1:1:0:23</ip>
#           <prefix-length>126</prefix-length>
#         </address>
#       </ipv6>
#     </interface>
#     <interface>
#       <name>Loopback0</name>
#       <description>Loopback</description>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:softwareLoopback</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip">
#         <address>
#           <ip>192.168.0.7</ip>
#           <netmask>255.255.255.255</netmask>
#         </address>
#       </ipv4>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip">
#         <address>
#           <ip>2001:db8:b:0:1::2</ip>
#           <prefix-length>128</prefix-length>
#         </address>
#       </ipv6>
#     </interface>
#   </interfaces>
# </data>

# %%
filter = '''
<interfaces xmlns="urn:ietf:params:xml:ns:yang:ietf-interfaces">
  <interface>
    <name/>
    <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip">
      <address><ip/></address>
    </ipv4>
  </interface>
</interfaces>
'''
c = m.get_config(source='running', filter=('subtree', filter))
pretty_print(c)
# Out:
# <data xmlns="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0">
#   <interfaces xmlns="urn:ietf:params:xml:ns:yang:ietf-interfaces">
#     <interface>
#       <name>GigabitEthernet1</name>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip">
#         <address>
#           <ip>172.16.1.158</ip>
#         </address>
#       </ipv4>
#     </interface>
#     <interface>
#       <name>GigabitEthernet2</name>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip">
#         <address>
#           <ip>10.0.0.21</ip>
#         </address>
#       </ipv4>
#     </interface>
#     <interface>
#       <name>GigabitEthernet3</name>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip">
#         <address>
#           <ip>10.0.0.29</ip>
#         </address>
#       </ipv4>
#     </interface>
#     <interface>
#       <name>GigabitEthernet4</name>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip">
#         <address>
#           <ip>10.0.0.25</ip>
#         </address>
#       </ipv4>
#     </interface>
#     <interface>
#       <name>GigabitEthernet5</name>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip">
#         <address>
#           <ip>10.0.0.33</ip>
#         </address>
#       </ipv4>
#     </interface>
#     <interface>
#       <name>Loopback0</name>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip">
#         <address>
#           <ip>192.168.0.7</ip>
#         </address>
#       </ipv4>
#     </interface>
#   </interfaces>
# </data>
