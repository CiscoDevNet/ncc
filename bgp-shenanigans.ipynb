# %% [markdown]
# # BGP Shenanigans

# %% [markdown]
# ## Connecting to a Device

# %% [markdown]
# Let's define some variables:

# %%
HOST = '172.26.170.252'
PORT = 830
USER = 'cisco'
PASS = 'C1sdevops'

# %% [markdown]
# Now let's establish a NETCONF session to that box using ncclient:

# %%
from ncclient import manager

def my_unknown_host_cb(host, fingerprint):
    return True
    
m = manager.connect(host=HOST, port=PORT, username=USER, password=PASS,
                    allow_agent=False,
                    look_for_keys=False,
                    hostkey_verify=False,
                    unknown_host_cb=my_unknown_host_cb)

# %% [markdown]
# ## Capabilities

# %% [markdown]
# Let's look at the capabilities presented by the thing we've just connected to:

# %%
print(m.server_capabilities)
# Out:
# ['urn:ietf:params:xml:ns:yang:smiv2:CISCO-IPSLA-ECHO-MIB?module=CISCO-IPSLA-ECHO-MIB&revision=2007-08-16', 'urn:cisco:params:xml:ns:yang:cisco-qos-common?module=cisco-qos-common&revision=2015-05-09', 'http://tail-f.com/ns/mibs/SNMPv2-MIB/200210160000Z?module=SNMPv2-MIB&revision=2002-10-16', 'http://tail-f.com/ns/mibs/SNMP-NOTIFICATION-MIB/200210140000Z?module=SNMP-NOTIFICATION-MIB&revision=2002-10-14', 'urn:ietf:params:xml:ns:yang:smiv2:CISCO-CBP-TARGET-TC-MIB?module=CISCO-CBP-TARGET-TC-MIB&revision=2006-03-24', 'urn:ietf:params:netconf:capability:notification:1.0', 'http://tail-f.com/ns/webui?module=tailf-webui&revision=2013-03-07', 'urn:ietf:params:xml:ns:yang:smiv2:CISCO-PRODUCTS-MIB?module=CISCO-PRODUCTS-MIB&revision=2014-11-06', 'urn:ietf:params:xml:ns:yang:smiv2:CISCO-UBE-MIB?module=CISCO-UBE-MIB&revision=2010-11-29', 'urn:ietf:params:netconf:capability:rollback-on-error:1.0', 'urn:ietf:params:xml:ns:yang:smiv2:CISCO-AAA-SESSION-MIB?module=CISCO-AAA-SESSION-MIB&revision=2006-03-21', 'http://tail-f.com/yang/common-monitoring?module=tailf-common-monitoring&revision=2013-06-14', 'urn:ietf:params:xml:ns:yang:smiv2:CISCO-RF-MIB?module=CISCO-RF-MIB&revision=2005-09-01', 'urn:ietf:params:xml:ns:yang:smiv2:ENTITY-MIB?module=ENTITY-MIB&revision=2005-08-10', 'urn:ietf:params:xml:ns:yang:smiv2:IP-FORWARD-MIB?module=IP-FORWARD-MIB&revision=1996-09-19', 'urn:cisco:params:xml:ns:yang:cisco-qos-action-qlimit-cfg?module=cisco-qos-action-qlimit-cfg&revision=2015-05-09&features=qos-grp-based-queuing-support,mpls-exp-based-queuing-support,disc-class-based-queuing-support', 'urn:ietf:params:xml:ns:yang:smiv2:CISCO-BULK-FILE-MIB?module=CISCO-BULK-FILE-MIB&revision=2002-06-10', 'urn:ietf:params:xml:ns:yang:iana-crypt-hash?module=iana-crypt-hash&revision=2014-04-04&features=crypt-hash-sha-512,crypt-hash-sha-256,crypt-hash-md5', 'urn:ietf:params:xml:ns:yang:smiv2:ENTITY-STATE-TC-MIB?module=ENTITY-STATE-TC-MIB&revision=2005-11-22', 'urn:ietf:params:xml:ns:yang:smiv2:EtherLike-MIB?module=EtherLike-MIB&revision=2003-09-19', 'urn:ietf:params:xml:ns:yang:smiv2:CISCO-EIGRP-MIB?module=CISCO-EIGRP-MIB&revision=2004-11-16', 'urn:cisco:params:xml:ns:yang:table-map?module=cisco-table-map&revision=2015-05-19&features=table-map-template-support', 'http://tail-f.com/ns/mibs/SNMP-MPD-MIB/200210140000Z?module=SNMP-MPD-MIB&revision=2002-10-14', 'urn:ietf:params:xml:ns:yang:smiv2:CISCO-CDP-MIB?module=CISCO-CDP-MIB&revision=2005-03-21', 'urn:ietf:params:xml:ns:yang:ietf-interfaces?module=ietf-interfaces&revision=2014-05-08&features=pre-provisioning,if-mib,arbitrary-names&deviations=ietf-ip-devs', 'urn:ietf:params:netconf:capability:with-defaults:1.0?basic-mode=report-all', 'http://tail-f.com/yang/confd-monitoring?module=tailf-confd-monitoring&revision=2013-06-14', 'urn:ietf:params:xml:ns:yang:common-mpls-types?module=common-mpls-types&revision=2015-05-28', 'urn:ietf:params:xml:ns:yang:smiv2:CISCO-QOS-PIB-MIB?module=CISCO-QOS-PIB-MIB&revision=2007-08-29', 'urn:ietf:params:xml:ns:yang:smiv2:CISCO-OSPF-MIB?module=CISCO-OSPF-MIB&revision=2003-07-18', 'urn:ietf:params:xml:ns:yang:smiv2:IPV6-FLOW-LABEL-MIB?module=IPV6-FLOW-LABEL-MIB&revision=2003-08-28', 'urn:ietf:params:xml:ns:yang:smiv2:SNMPv2-MIB?module=SNMPv2-MIB&revision=2002-10-16', 'urn:ietf:params:xml:ns:yang:smiv2:DISMAN-EVENT-MIB?module=DISMAN-EVENT-MIB&revision=2000-10-16', 'urn:ietf:params:xml:ns:yang:smiv2:CISCO-VLAN-IFTABLE-RELATIONSHIP-MIB?module=CISCO-VLAN-IFTABLE-RELATIONSHIP-MIB&revision=2013-07-15', 'urn:ietf:params:xml:ns:yang:smiv2:CISCO-OSPF-TRAP-MIB?module=CISCO-OSPF-TRAP-MIB&revision=2003-07-18', 'urn:ietf:params:xml:ns:yang:ietf-diffserv-target?module=ietf-diffserv-target&revision=2015-04-07&features=target-inline-policy-config', 'urn:ietf:params:xml:ns:yang:smiv2:CISCO-NTP-MIB?module=CISCO-NTP-MIB&revision=2006-07-31', 'urn:ietf:params:xml:ns:yang:smiv2:IF-MIB?module=IF-MIB&revision=2000-06-14', 'urn:ietf:params:xml:ns:yang:ietf-yang-types?module=ietf-yang-types&revision=2013-07-15', 'urn:ietf ...

# %% [markdown]
# Ok, that's a bit messy, so let's tidy it up a bit and look, initially, at all the base netconf capabilities:

# %%
nc_caps = [c for c in m.server_capabilities if c.startswith('urn:ietf:params:netconf')]
for c in nc_caps:
    print(c)
# Out:
# urn:ietf:params:netconf:capability:notification:1.0
# urn:ietf:params:netconf:capability:rollback-on-error:1.0
# urn:ietf:params:netconf:capability:with-defaults:1.0?basic-mode=report-all
# urn:ietf:params:netconf:capability:interleave:1.0
# urn:ietf:params:netconf:capability:validate:1.0
# urn:ietf:params:netconf:capability:validate:1.1
# urn:ietf:params:netconf:base:1.0
# urn:ietf:params:netconf:base:1.1
# urn:ietf:params:netconf:capability:writable-running:1.0
# urn:ietf:params:netconf:capability:xpath:1.0

# %% [markdown]
# And now let's look at the capabilities that are related to model support:

# %%
import re

for c in m.server_capabilities:
    model = re.search('module=([^&]*)&', c)
    if model is not None:
        print("{}".format(model.group(1)))

        revision = re.search('revision=([0-9]{4}-[0-9]{2}-[0-9]{2})', c)
        if revision is not None:
            print("  revision = {}".format(revision.group(1)))

        deviations = re.search('deviations=([a-zA-Z0-9\-,]+)($|&)',c)
        if deviations is not None:
            print("  deviations = {}".format(deviations.group(1)))

        features = re.search('features=([a-zA-Z0-9\-,]+)($|&)',c)
        if features is not None:
            print("  features = {}".format(features.group(1)))
# Out:
# CISCO-IPSLA-ECHO-MIB
#   revision = 2007-08-16
# cisco-qos-common
#   revision = 2015-05-09
# SNMPv2-MIB
#   revision = 2002-10-16
# SNMP-NOTIFICATION-MIB
#   revision = 2002-10-14
# CISCO-CBP-TARGET-TC-MIB
#   revision = 2006-03-24
# tailf-webui
#   revision = 2013-03-07
# CISCO-PRODUCTS-MIB
#   revision = 2014-11-06
# CISCO-UBE-MIB
#   revision = 2010-11-29
# CISCO-AAA-SESSION-MIB
#   revision = 2006-03-21
# tailf-common-monitoring
#   revision = 2013-06-14
# CISCO-RF-MIB
#   revision = 2005-09-01
# ENTITY-MIB
#   revision = 2005-08-10
# IP-FORWARD-MIB
#   revision = 1996-09-19
# cisco-qos-action-qlimit-cfg
#   revision = 2015-05-09
#   features = qos-grp-based-queuing-support,mpls-exp-based-queuing-support,disc-class-based-queuing-support
# CISCO-BULK-FILE-MIB
#   revision = 2002-06-10
# iana-crypt-hash
#   revision = 2014-04-04
#   features = crypt-hash-sha-512,crypt-hash-sha-256,crypt-hash-md5
# ENTITY-STATE-TC-MIB
#   revision = 2005-11-22
# EtherLike-MIB
#   revision = 2003-09-19
# CISCO-EIGRP-MIB
#   revision = 2004-11-16
# cisco-table-map
#   revision = 2015-05-19
#   features = table-map-template-support
# SNMP-MPD-MIB
#   revision = 2002-10-14
# CISCO-CDP-MIB
#   revision = 2005-03-21
# ietf-interfaces
#   revision = 2014-05-08
#   deviations = ietf-ip-devs
#   features = pre-provisioning,if-mib,arbitrary-names
# tailf-confd-monitoring
#   revision = 2013-06-14
# common-mpls-types
#   revision = 2015-05-28
# CISCO-QOS-PIB-MIB
#   revision = 2007-08-29
# CISCO-OSPF-MIB
#   revision = 2003-07-18
# IPV6-FLOW-LABEL-MIB
#   revision = 2003-08-28
# SNMPv2-MIB
#   revision = 2002-10-16
# DISMAN-EVENT-MIB
#   revision = 2000-10-16
# CISCO-VLAN-IFTABLE-RELATIONSHIP-MIB
#   revision = 2013-07-15
# CISCO-OSPF-TRAP-MIB
#   revision = 2003-07-18
# ietf-diffserv-target
#   revision = 2015-04-07
#   features = target-inline-policy-config
# CISCO-NTP-MIB
#   revision = 2006-07-31
# IF-MIB
#   revision = 2000-06-14
# ietf-yang-types
#   revision = 2013-07-15
# CISCO-SYSLOG-MIB
#   revision = 2005-12-03
# CISCO-TAP2-MIB
#   revision = 2009-11-06
# cisco-ia
#   revision = 2016-05-20
# CISCO-DYNAMIC-TEMPLATE-MIB
#   revision = 2007-09-06
# ietf-netconf-monitoring
#   revision = 2010-10-04
# policy-attr
#   revision = 2015-04-27
# ned
#   revision = 2016-06-09
#   deviations = ned-switching-devs
# cisco-policy
#   revision = 2016-03-30
# cisco-ospf
#   revision = 2016-03-30
#   features = graceful-shutdown,flood-reduction,database-filter
# cisco-qos-action-marking-cfg
#   revision = 2015-05-09
#   features = set-wlan-user-priority-support,set-vlan-inner-support,set-srp-priority-support,set-qos-grp-support,set-prec-tunnel-support,set-prec-support,set-mpls-exp-top-support,set-mpls-exp-imp-support,set-fr-fecn-becn-support,set-fr-de-support,set-dscp-tunnel-support,set-discard-class-support,set-dei-support,set-dei-imp-support,set-cos-support,set-cos-inner-suppport,set-atm-clp-support
# CISCO-DYNAMIC-TEMPLATE-TC-MIB
#   revision = 2012-01-27
# SNMP-VIEW-BASED-ACM-MIB
#   revision = 2002-10-16
# CISCO-SMI
#   revision = 2012-08-29
# CISCO-CBP-TC-MIB
#   revision = 2008-06-24
# DISMAN-EXPRESSION-MIB
#   revision = 2000-10-16
# CISCO-IPSLA-JITTER-MIB
#   revision = 2007-07-24
# ietf-ipv4-unicast-routing
#   revision = 2015-05-25
# CISCO-FTP-CLIENT-MIB
#   revision = 2006-03-31
# CISCO-CONFIG-MAN-MIB
#   revision = 2007-04-27
# INTEGRATED-SERVICES-MIB
#   revision = 1995-11-03
# cisco-policy-target
#   revision = 2016-03-30
# pim
#   revision = 2014-06-27
#   features = bsr,auto-rp
# CISCO-AAA-SERVER-MIB
#   revision = 2003-11-17
# P-BRIDGE-MIB
#   revision = 2006-01-09
# cisco-policy-filters
#   revision = 2016-03-30
# CISCO-IETF-BFD-MIB
#   revision = 2011-04-16
# CISCO-ENTITY-FRU-CONTROL-MIB
#   revision = 2013-08-19
# BRIDGE-MIB
#   revision = 2005-09-19
# CISCO-CEF-TC
#   revision = 2005-09-30
# SNMP-FRAMEWORK-MIB
#   revision = 2002-10-14
# cisco-bgp-state
#   revision = 2015-10-16
# CISCO-TC
#   revision = 2011-11-11
# EXPRESSION-MIB
#   revision = 2005-11-24
# ietf-netconf-notifications
#   revision = 2012-02-06
# CISCO-IPSEC-FLOW-MONITOR-MIB
#   revision = 2007-10-24
# CISCO-BGP4-MIB
#   revision = 2010-09-30
# cisco-ethernet
#   revision = 2016-05-10
# iana-if-type
#   revision = 2014-05-08
# HCNUM-TC
#   revision = 2000-06-08
# CISCO-CONFIG-COPY-MIB
#   revision = 2005-04-06
# ietf-yang-smiv2
#   revision = 2012-06-22
# CISCO-IPSLA-TC-MIB
#   revision = 2007-03-23
# cisco-qos-action-oper
#   revision = 2015-05-09
#   features = queue-peak-size-stats-support,priority-bandwidth-exceed-drops-support,marking-stats-support,drop-pkts-no-buffer-stats-support,drop-pkts-flow-stats-support,aggregate-priority-stats-support
# CISCO-HSRP-MIB
#   revision = 2010-09-06
# tailf-acm
#   revision = 2013-03-07
# IANAifType-MIB
#   revision = 2006-03-31
# ENTITY-SENSOR-MIB
#   revision = 2002-12-16
# IGMP-STD-MIB
#   revision = 2000-09-28
# CISCO-CONTEXT-MAPPING-MIB
#   revision = 2008-11-22
# CISCO-IMAGE-LICENSE-MGMT-MIB
#   revision = 2007-10-16
# CISCO-CBP-TARGET-MIB
#   revision = 2006-05-24
# CISCO-IPSEC-POLICY-MAP-MIB
#   revision = 2000-08-17
# CISCO-IETF-ISIS-MIB
#   revision = 2005-08-16
# IPV6-TC
#   revision = 1998-12-01
# VPN-TC-STD-MIB
#   revision = 2005-11-15
# ietf-ospf
#   revision = 2015-03-09
#   deviations = ietf-ospf-devs
#   features = ttl-security,te-rid,router-id,remote-lfa,prefix-suppression,ospfv3-authentication-ipsec,nsr,node-flag,multi-topology,multi-area-adj,mtu-ignore,max-lsa,max-ecmp,lls,lfa,ldp-igp-sync,ldp-igp-autoconfig,interface-inheritance,instance-inheritance,graceful-restart,fast-reroute,demand-circuit,bfd,auto-cost,area-inheritance,admin-control
# UDP-MIB
#   revision = 2005-05-20
# CISCO-FIREWALL-TC
#   revision = 2006-03-03
# IANA-RTPROTO-MIB
#   revision = 2000-09-26
# CISCO-IP-URPF-MIB
#   revision = 2011-12-29
# CISCO-ENTITY-SENSOR-MIB
#   revision = 2015-01-15
# CISCO-DOT3-OAM-MIB
#   revision = 2006-05-31
# CISCO-MEDIA-GATEWAY-MIB
#   revision = 2009-02-25
# ietf-diffserv-classifier
#   revision = 2015-04-07
#   features = policy-inline-classifier-config
# IANA-ADDRESS-FAMILY-NUMBERS-MIB
#   revision = 2000-09-08
# OSPF-TRAP-MIB
#   revision = 2006-11-10
# nvo
#   revision = 2015-06-02
#   deviations = nvo-devs
# CISCO-EMBEDDED-EVENT-MGR-MIB
#   revision = 2006-11-07
# SNMP-TARGET-MIB
#   revision = 2002-10-14
# PerfHist-TC-MIB
#   revision = 1998-11-07
# NOTIFICATION-LOG-MIB
#   revision = 2000-11-27
# DRAFT-MSDP-MIB
#   revision = 1999-12-16
# DIFFSERV-MIB
#   revision = 2002-02-07
# CISCO-RTTMON-TC-MIB
#   revision = 2012-05-25
# CISCO-DATA-COLLECTION-MIB
#   revision = 2002-10-30
# CISCO-VPDN-MGMT-MIB
#   revision = 2009-06-16
# CISCO-PING-MIB
#   revision = 2001-08-28
# CISCO-IP-LOCAL-POOL-MIB
#   revision = 2007-11-12
# TRANSPORT-ADDRESS-MIB
#   revision = 2002-11-01
# DIFFSERV-DSCP-TC
#   revision = 2002-05-09
# ietf-inet-types
#   revision = 2013-07-15
# OSPF-MIB
#   revision = 2006-11-10
# NHRP-MIB
#   revision = 1999-08-26
# ietf-routing
#   revision = 2015-05-25
#   deviations = ietf-ipv4-unicast-routing-devs,ietf-ipv6-unicast-routing-devs,ietf-ospf-devs,ietf-routing-devs
#   features = router-id,multiple-ribs
# CISCO-VTP-MIB
#   revision = 2013-10-14
# ETHER-WIS
#   revision = 2003-09-19
# ietf-diffserv-action
#   revision = 2015-04-07
#   features = priority-rate-burst-support,hierarchial-policy-support,aqm-red-support
# PIM-MIB
#   revision = 2000-09-28
# tailf-netconf-monitoring
#   revision = 2014-11-13
# CISCO-IPSLA-AUTOMEASURE-MIB
#   revision = 2007-06-13
# SNMP-PROXY-MIB
#   revision = 2002-10-14
# CISCO-ETHERLIKE-EXT-MIB
#   revision = 2010-06-04
# common-mpls-static
#   revision = 2015-07-22
#   deviations = common-mpls-static-devs
# TCP-MIB
#   revision = 2005-02-18
# CISCO-PIM-MIB
#   revision = 2000-11-02
# ietf-ip
#   revision = 2014-01-08
#   features = ipv6-privacy-autoconf,ipv4-non-contiguous-netmasks
# ietf-netconf-acm
#   revision = 2012-02-22
# SNMP-USER-BASED-SM-MIB
#   revision = 2002-10-16
# CISCO-ENTITY-ALARM-MIB
#   revision = 1999-07-06
# CISCO-ST-TC
#   revision = 2012-08-08
# ietf-key-chain
#   revision = 2015-02-24
#   features = independent-send-accept-lifetime,hex-key-string,accept-tolerance
# CISCO-HSRP-EXT-MIB
#   revision = 2010-09-02
# ned-switching-augs
#   revision = 2016-04-21
# INET-ADDRESS-MIB
#   revision = 2005-02-04
# cisco-odm
#   revision = 2016-05-16
# TUNNEL-MIB
#   revision = 2005-05-16
# cisco-self-mgmt
#   revision = 2016-05-14
# cisco-acl-oper
#   revision = 2016-03-30
# CISCO-RADIUS-EXT-MIB
#   revision = 2010-05-25
# CISCO-IMAGE-MIB
#   revision = 1995-08-15
# CISCO-NBAR-PROTOCOL-DISCOVERY-MIB
#   revision = 2002-08-16
# CISCO-ENVMON-MIB
#   revision = 2003-12-01
# IPMROUTE-STD-MIB
#   revision = 2000-09-22
# SNMP-FRAMEWORK-MIB
#   revision = 2002-10-14
# INT-SERV-MIB
#   revision = 1997-10-03
# CISCO-IF-EXTENSION-MIB
#   revision = 2013-03-13
# tailf-aaa
#   revision = 2015-06-16
# CISCO-ENTITY-VENDORTYPE-OID-MIB
#   revision = 2014-12-09
# CISCO-BGP-POLICY-ACCOUNTING-MIB
#   revision = 2002-07-26
# ietf-diffserv-policy
#   revision = 2015-04-07
#   features = policy-template-support,hierarchial-policy-support
# BGP4-MIB
#   revision = 1994-05-05
# CISCO-IPMROUTE-MIB
#   revision = 2005-03-07
# RMON-MIB
#   revision = 2000-05-11
# SNMP-COMMUNITY-MIB
#   revision = 2003-08-06
# SNMP-TARGET-MIB
#   revision = 1998-08-04
# policy-types
#   revision = 2013-10-07
#   features = protocol-name-support,match-wlan-user-priority-support,match-vpls-support,match-vlan-support,match-vlan-inner-support,match-src-mac-support,match-security-group-support,match-qos-group-support,match-prec-support,match-packet-length-support,match-mpls-exp-top-support,match-mpls-exp-imp-support,match-metadata-support,match-ipv6-acl-support,match-ipv6-acl-name-support,match-ipv4-acl-support,match-ipv4-acl-name-support,match-ip-rtp-support,match-input-interface-support,match-fr-dlci-support,match-fr-de-support,match-flow-record-support,match-flow-ip-support,match-dst-mac-support,match-discard-class-support,match-dei-support,match-dei-inner-support,match-cos-support,match-cos-inner-support,match-class-map-support,match-atm-vci-support,match-atm-clp-support,match-application-support
# ENTITY-STATE-MIB
#   revision = 2005-11-22
# ietf-ipv6-unicast-routing
#   revision = 2015-05-25
# CISCO-PTP-MIB
#   revision = 2011-01-28
# CISCO-VLAN-MEMBERSHIP-MIB
#   revision = 2007-12-14
# IP-MIB
#   revision = 2006-02-02
# CISCO-IP-TAP-MIB
#   revision = 2004-03-11
# CISCO-STP-EXTENSIONS-MIB
#   revision = 2013-03-07

# %% [markdown]
# ## Enough!! What About Config?
#
# The ncclient library provides for some simple operations. Let's skip thinking about schemas and stuff like that. Instead let's focus on config and getting end setting it. For that, ncclient provides two methods:
#
# * get_config - takes a target data store and an optional filter
# * edit_config - takes a target data store and an XML document with the edit request

# %% [markdown]
# ### But let's define some utilities first!

# %%
from lxml import etree

def pretty_print(nc_retval):
        print(etree.tostring(etree.fromstring(nc_retval.data_xml), pretty_print=True))

# %% [markdown]
# ### Getting Config
#
# Let's look at some simple requests...

# %%
c = m.get_config(source='running')
pretty_print(c)
# Out:
# <data xmlns="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0">
#   <native xmlns="http://cisco.com/ns/yang/ned/ios">
#     <device-model-version>
#       <major>2</major>
#       <minor>1</minor>
#       <bug-fix>0</bug-fix>
#     </device-model-version>
#     <service>
#       <timestamps>
#         <debug>
#           <datetime>
#             <msec/>
#           </datetime>
#         </debug>
#         <log>
#           <datetime>
#             <msec/>
#           </datetime>
#         </log>
#       </timestamps>
#     </service>
#     <platform>
#       <punt-keepalive>
#         <disable-kernel-core>false</disable-kernel-core>
#       </punt-keepalive>
#     </platform>
#     <enable>
#       <password>
#         <secret>C1sdevops</secret>
#       </password>
#     </enable>
#     <username>
#       <name>admin</name>
#       <password>
#         <encryption>0</encryption>
#         <password>C1sdevops</password>
#       </password>
#     </username>
#     <username>
#       <name>cisco</name>
#       <password>
#         <encryption>0</encryption>
#         <password>C1sdevops</password>
#       </password>
#     </username>
#     <vrf>
#       <definition>
#         <name>Mgmt-vrf</name>
#         <address-family>
#           <ipv4/>
#           <ipv6/>
#         </address-family>
#       </definition>
#     </vrf>
#     <ip>
#       <domain>
#         <name>cisco.com</name>
#       </domain>
#       <forward-protocol>
#         <protocol>nd</protocol>
#       </forward-protocol>
#       <ftp>
#         <source-interface>
#           <GigabitEthernet>0/0</GigabitEthernet>
#         </source-interface>
#       </ftp>
#       <http>
#         <authentication>
#           <local/>
#         </authentication>
#         <server>true</server>
#         <secure-server>true</secure-server>
#       </http>
#       <name-server>64.102.6.247</name-server>
#       <route>
#         <ip-route-interface-forwarding-list>
#           <prefix>0.0.0.0</prefix>
#           <mask>0.0.0.0</mask>
#           <fwd-list>
#             <fwd>172.26.170.1</fwd>
#           </fwd-list>
#         </ip-route-interface-forwarding-list>
#         <vrf>
#           <name>Mgmt-vrf</name>
#           <ip-route-interface-forwarding-list>
#             <prefix>0.0.0.0</prefix>
#             <mask>0.0.0.0</mask>
#             <fwd-list>
#               <fwd>172.26.170.1</fwd>
#             </fwd-list>
#           </ip-route-interface-forwarding-list>
#         </vrf>
#       </route>
#       <routing/>
#       <ssh>
#         <source-interface>GigabitEthernet0/0</source-interface>
#       </ssh>
#       <tftp>
#         <source-interface>
#           <GigabitEthernet>0/0</GigabitEthernet>
#         </source-interface>
#       </tftp>
#       <access-list>
#         <extended>
#           <name>AutoQos-4.0-wlan-Acl-Bulk-Data</name>
#           <access-list-seq-rule>
#             <sequence>10</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>22</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>20</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>465</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>30</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>143</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>40</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>993</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>50</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>995</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>60</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>1914</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>70</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>ftp</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>80</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>ftp-data</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>90</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>smtp</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>100</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>pop3</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#         </extended>
#         <extended>
#           <name>AutoQos-4.0-wlan-Acl-MultiEnhanced-Conf</name>
#           <access-list-seq-rule>
#             <sequence>10</sequence>
#             <permit>
#               <acl-protocol>
#                 <udp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <port-match-oper>
#                         <range>
#                           <port-operand1>
#                             <port-operand>16384</port-operand>
#                             <udp-port-operand>32767</udp-port-operand>
#                           </port-operand1>
#                         </range>
#                       </port-match-oper>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </udp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>20</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <range>
#                           <port-operand1>
#                             <port-operand>50000</port-operand>
#                             <udp-port-operand>59999</udp-port-operand>
#                           </port-operand1>
#                         </range>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#         </extended>
#         <extended>
#           <name>AutoQos-4.0-wlan-Acl-Scavanger</name>
#           <access-list-seq-rule>
#             <sequence>10</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <range>
#                           <port-operand1>
#                             <port-operand>2300</port-operand>
#                             <udp-port-operand>2400</udp-port-operand>
#                           </port-operand1>
#                         </range>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>20</sequence>
#             <permit>
#               <acl-protocol>
#                 <udp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <port-match-oper>
#                         <range>
#                           <port-operand1>
#                             <port-operand>2300</port-operand>
#                             <udp-port-operand>2400</udp-port-operand>
#                           </port-operand1>
#                         </range>
#                       </port-match-oper>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </udp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>30</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <range>
#                           <port-operand1>
#                             <port-operand>6881</port-operand>
#                             <udp-port-operand>6999</udp-port-operand>
#                           </port-operand1>
#                         </range>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>40</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <range>
#                           <port-operand1>
#                             <port-operand>28800</port-operand>
#                             <udp-port-operand>29100</udp-port-operand>
#                           </port-operand1>
#                         </range>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>50</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>1214</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>60</sequence>
#             <permit>
#               <acl-protocol>
#                 <udp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <port-match-oper>
#                         <eq>
#                           <port-operand>1214</port-operand>
#                         </eq>
#                       </port-match-oper>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </udp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>70</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>3689</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>80</sequence>
#             <permit>
#               <acl-protocol>
#                 <udp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <port-match-oper>
#                         <eq>
#                           <port-operand>3689</port-operand>
#                         </eq>
#                       </port-match-oper>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </udp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>90</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>11999</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#         </extended>
#         <extended>
#           <name>AutoQos-4.0-wlan-Acl-Signaling</name>
#           <access-list-seq-rule>
#             <sequence>10</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <range>
#                           <port-operand1>
#                             <port-operand>2000</port-operand>
#                             <udp-port-operand>2002</udp-port-operand>
#                           </port-operand1>
#                         </range>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>20</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <range>
#                           <port-operand1>
#                             <port-operand>5060</port-operand>
#                             <udp-port-operand>5061</udp-port-operand>
#                           </port-operand1>
#                         </range>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>30</sequence>
#             <permit>
#               <acl-protocol>
#                 <udp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <port-match-oper>
#                         <range>
#                           <port-operand1>
#                             <port-operand>5060</port-operand>
#                             <udp-port-operand>5061</udp-port-operand>
#                           </port-operand1>
#                         </range>
#                       </port-match-oper>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </udp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#         </extended>
#         <extended>
#           <name>AutoQos-4.0-wlan-Acl-Transactional-Data</name>
#           <access-list-seq-rule>
#             <sequence>10</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>443</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>20</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>1521</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>30</sequence>
#             <permit>
#               <acl-protocol>
#                 <udp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <port-match-oper>
#                         <eq>
#                           <port-operand>1521</port-operand>
#                         </eq>
#                       </port-match-oper>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </udp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>40</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>1526</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>50</sequence>
#             <permit>
#               <acl-protocol>
#                 <udp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <port-match-oper>
#                         <eq>
#                           <port-operand>1526</port-operand>
#                         </eq>
#                       </port-match-oper>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </udp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>60</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>1575</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>70</sequence>
#             <permit>
#               <acl-protocol>
#                 <udp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <port-match-oper>
#                         <eq>
#                           <port-operand>1575</port-operand>
#                         </eq>
#                       </port-match-oper>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </udp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>80</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>1630</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>90</sequence>
#             <permit>
#               <acl-protocol>
#                 <udp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <port-match-oper>
#                         <eq>
#                           <port-operand>1630</port-operand>
#                         </eq>
#                       </port-match-oper>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </udp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>100</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>1527</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>110</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>6200</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>120</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>3389</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>130</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>5985</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>140</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>8080</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#         </extended>
#         <extended>
#           <name>CISCO-CWA-URL-REDIRECT-ACL</name>
#           <access-list-seq-rule>
#             <sequence>100</sequence>
#             <deny>
#               <acl-protocol>
#                 <udp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <port-match-oper>
#                         <eq>
#                           <port-operand>domain</port-operand>
#                         </eq>
#                       </port-match-oper>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </udp>
#               </acl-protocol>
#             </deny>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>101</sequence>
#             <deny>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>domain</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </deny>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>102</sequence>
#             <deny>
#               <acl-protocol>
#                 <udp>
#                   <source-destination-match>
#                     <any/>
#                     <src-udp-eq>bootps</src-udp-eq>
#                     <dst-any/>
#                   </source-destination-match>
#                 </udp>
#               </acl-protocol>
#             </deny>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>103</sequence>
#             <deny>
#               <acl-protocol>
#                 <udp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <port-match-oper>
#                         <eq>
#                           <udp-port-operand>bootpc</udp-port-operand>
#                         </eq>
#                       </port-match-oper>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </udp>
#               </acl-protocol>
#             </deny>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>104</sequence>
#             <deny>
#               <acl-protocol>
#                 <udp>
#                   <source-destination-match>
#                     <any/>
#                     <src-udp-eq>bootpc</src-udp-eq>
#                     <dst-any/>
#                   </source-destination-match>
#                 </udp>
#               </acl-protocol>
#             </deny>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>105</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>www</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#         </extended>
#         <extended>
#           <name>IP-Adm-V4-Int-ACL-global</name>
#           <access-list-seq-rule>
#             <sequence>10</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>www</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>20</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>443</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#         </extended>
#         <extended>
#           <name>preauth_v4</name>
#           <access-list-seq-rule>
#             <sequence>10</sequence>
#             <permit>
#               <acl-protocol>
#                 <udp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <port-match-oper>
#                         <eq>
#                           <port-operand>domain</port-operand>
#                         </eq>
#                       </port-match-oper>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </udp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>20</sequence>
#             <permit>
#               <acl-protocol>
#                 <tcp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <tcp-match>
#                         <eq>
#                           <port-operand>domain</port-operand>
#                         </eq>
#                       </tcp-match>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </tcp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>30</sequence>
#             <permit>
#               <acl-protocol>
#                 <udp>
#                   <source-destination-match>
#                     <any/>
#                     <src-udp-eq>bootps</src-udp-eq>
#                     <dst-any/>
#                   </source-destination-match>
#                 </udp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>40</sequence>
#             <permit>
#               <acl-protocol>
#                 <udp>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                     <acl-match-attribute>
#                       <port-match-oper>
#                         <eq>
#                           <udp-port-operand>bootpc</udp-port-operand>
#                         </eq>
#                       </port-match-oper>
#                     </acl-match-attribute>
#                   </source-destination-match>
#                 </udp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>50</sequence>
#             <permit>
#               <acl-protocol>
#                 <udp>
#                   <source-destination-match>
#                     <any/>
#                     <src-udp-eq>bootpc</src-udp-eq>
#                     <dst-any/>
#                   </source-destination-match>
#                 </udp>
#               </acl-protocol>
#             </permit>
#           </access-list-seq-rule>
#           <access-list-seq-rule>
#             <sequence>60</sequence>
#             <deny>
#               <acl-protocol>
#                 <ip>
#                   <source-destination-match>
#                     <any/>
#                     <dst-any/>
#                   </source-destination-match>
#                 </ip>
#               </acl-protocol>
#             </deny>
#           </access-list-seq-rule>
#         </extended>
#       </access-list>
#     </ip>
#     <vlan>
#       <vlan-list>
#         <id>10</id>
#       </vlan-list>
#     </vlan>
#     <interface>
#       <GigabitEthernet>
#         <name>0/0</name>
#         <negotiation>
#           <auto>true</auto>
#         </negotiation>
#         <description>boom</description>
#         <vrf>
#           <forwarding>Mgmt-vrf</forwarding>
#         </vrf>
#         <ip>
#           <address>
#             <primary>
#               <address>172.26.170.252</address>
#               <mask>255.255.254.0</mask>
#             </primary>
#           </address>
#         </ip>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/1</name>
#         <description>boom</description>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/10</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/11</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/12</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/13</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/14</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/15</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/16</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/17</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/18</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/19</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/2</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/20</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/21</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/22</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/23</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/24</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/25</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/26</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/27</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/28</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/29</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/3</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/30</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/31</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/32</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/33</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/34</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/35</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/36</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/37</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/38</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/39</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/4</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/40</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/41</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/42</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/43</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/44</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/45</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/46</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/47</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/48</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/5</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/6</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/7</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/8</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/0/9</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/1/1</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/1/2</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/1/3</name>
#       </GigabitEthernet>
#       <GigabitEthernet>
#         <name>1/1/4</name>
#       </GigabitEthernet>
#       <TenGigabitEthernet>
#         <name>1/1/1</name>
#       </TenGigabitEthernet>
#       <TenGigabitEthernet>
#         <name>1/1/2</name>
#       </TenGigabitEthernet>
#       <TenGigabitEthernet>
#         <name>1/1/3</name>
#       </TenGigabitEthernet>
#       <TenGigabitEthernet>
#         <name>1/1/4</name>
#       </TenGigabitEthernet>
#       <Vlan>
#         <name>1</name>
#         <ip>
#           <no-address>
#             <address>false</address>
#           </no-address>
#         </ip>
#         <shutdown/>
#       </Vlan>
#     </interface>
#     <diagnostic>
#       <bootup>
#         <level>minimal</level>
#       </bootup>
#     </diagnostic>
#     <switch>
#       <number>1</number>
#       <provision>ws-c3850-48u</provision>
#     </switch>
#     <class-map>
#       <name>non-client-nrt-class</name>
#       <prematch>match-any</prematch>
#     </class-map>
#     <class-map>
#       <name>system-cpp-default</name>
#       <prematch>match-any</prematch>
#       <description>DHCP snooping, show forward and rest of traffic</description>
#     </class-map>
#     <class-map>
#       <name>system-cpp-police-control-low-priority</name>
#       <prematch>match-any</prematch>
#       <description>ICMP redirect and general punt</description>
#     </class-map>
#     <class-map>
#       <name>system-cpp-police-data</name>
#       <prematch>match-any</prematch>
#       <description>ICMP_GEN and BROADCAST</description>
#     </class-map>
#     <class-map>
#       <name>system-cpp-police-dot1x-auth</name>
#       <prematch>match-any</prematch>
#       <description>DOT1X Auth</description>
#     </class-map>
#     <class-map>
#       <name>system-cpp-police-forus</name>
#       <prematch>match-any</prematch>
#       <description>Forus Address resolution and Forus traffic</description>
#     </class-map>
#     <class-map>
#       <name>system-cpp-police-l2-control</name>
#       <prematch>match-any</prematch>
#       <description>L2 control</description>
#     </class-map>
#     <class-map>
#       <name>system-cpp-police-multicast</name>
#       <prematch>match-any</prematch>
#       <description>Transit Traffic and MCAST Data</description>
#     </class-map>
#     <class-map>
#       <name>system-cpp-police-multicast-end-station</name>
#       <prematch>match-any</prematch>
#       <description>MCAST END STATION</description>
#     </class-map>
#     <class-map>
#       <name>system-cpp-police-protocol-snooping</name>
#       <prematch>match-any</prematch>
#       <description>Protocol snooping</description>
#     </class-map>
#     <class-map>
#       <name>system-cpp-police-punt-webauth</name>
#       <prematch>match-any</prematch>
#       <description>Punt Webauth</description>
#     </class-map>
#     <class-map>
#       <name>system-cpp-police-routing-control</name>
#       <prematch>match-any</prematch>
#       <description>Routing control</description>
#     </class-map>
#     <class-map>
#       <name>system-cpp-police-sw-forward</name>
#       <prematch>match-any</prematch>
#       <description>Sw forwarding, SGT Cache Full, LOGGING</description>
#     </class-map>
#     <class-map>
#       <name>system-cpp-police-sys-data</name>
#       <prematch>match-any</prematch>
#       <description>Learning cache ovfl, Crypto Control, Exception, EGR Exception, NFL SAMPLED DATA, Gold Pkt, RPF Failed</description>
#     </class-map>
#     <class-map>
#       <name>system-cpp-police-topology-control</name>
#       <prematch>match-any</prematch>
#       <description>Topology control</description>
#     </class-map>
#     <class-map>
#       <name>system-cpp-police-wireless-priority1</name>
#       <prematch>match-any</prematch>
#       <description>Wireless priority 1</description>
#     </class-map>
#     <class-map>
#       <name>system-cpp-police-wireless-priority2</name>
#       <prematch>match-any</prematch>
#       <description>Wireless priority 2</description>
#     </class-map>
#     <class-map>
#       <name>system-cpp-police-wireless-priority3-4-5</name>
#       <prematch>match-any</prematch>
#       <description>Wireless priority 3,4 and 5</description>
#     </class-map>
#     <policy-map>
#       <name>c-C_C</name>
#       <class>
#         <name>class-default</name>
#         <action-list>
#           <action-type>set</action-type>
#           <set>
#             <dscp>
#               <dscp-val>default</dscp-val>
#             </dscp>
#           </set>
#         </action-list>
#       </class>
#     </policy-map>
#     <policy-map>
#       <name>port_child_policy</name>
#       <class>
#         <name>non-client-nrt-class</name>
#         <action-list>
#           <action-type>bandwidth</action-type>
#           <bandwidth>
#             <remaining>
#               <ratio>10</ratio>
#             </remaining>
#           </bandwidth>
#         </action-list>
#       </class>
# ...
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/2</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/20</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/21</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/22</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/23</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/24</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/25</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/26</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/27</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/28</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/29</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/3</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/30</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/31</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/32</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/33</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/34</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/35</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/36</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/37</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/38</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/39</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/4</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/40</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/41</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/42</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/43</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/44</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/45</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/46</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/47</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/48</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/5</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/6</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/7</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/8</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/0/9</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/1/1</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/1/2</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/1/3</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>GigabitEthernet1/1/4</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>TenGigabitEthernet1/1/1</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>TenGigabitEthernet1/1/2</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>TenGigabitEthernet1/1/3</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#     <interface>
#       <name>TenGigabitEthernet1/1/4</name>
#       <type xmlns:ianaift="urn:ietf:params:xml:ns:yang:iana-if-type">ianaift:ethernetCsmacd</type>
#       <enabled>true</enabled>
#       <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#       <ipv6 xmlns="urn:ietf:params:xml:ns:yang:ietf-ip"/>
#     </interface>
#   </interfaces>
#   <routing xmlns="urn:ietf:params:xml:ns:yang:ietf-routing">
#     <routing-instance>
#       <name>Mgmt-vrf</name>
#       <interfaces>
#         <interface>GigabitEthernet0/0</interface>
#       </interfaces>
#       <routing-protocols>
#         <routing-protocol>
#           <type>static</type>
#           <name>1</name>
#           <static-routes>
#             <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ipv4-unicast-routing">
#               <route>
#                 <destination-prefix>0.0.0.0/0</destination-prefix>
#                 <next-hop>
#                   <next-hop-address>172.26.170.1</next-hop-address>
#                 </next-hop>
#               </route>
#             </ipv4>
#           </static-routes>
#         </routing-protocol>
#       </routing-protocols>
#     </routing-instance>
#     <routing-instance>
#       <name>default</name>
#       <description>default-vrf [read-only]</description>
#       <interfaces/>
#       <routing-protocols>
#         <routing-protocol>
#           <type>static</type>
#           <name>1</name>
#           <static-routes>
#             <ipv4 xmlns="urn:ietf:params:xml:ns:yang:ietf-ipv4-unicast-routing">
#               <route>
#                 <destination-prefix>0.0.0.0/0</destination-prefix>
#                 <next-hop>
#                   <next-hop-address>172.26.170.1</next-hop-address>
#                 </next-hop>
#               </route>
#             </ipv4>
#           </static-routes>
#         </routing-protocol>
#       </routing-protocols>
#     </routing-instance>
#   </routing>
# </data>

# %% [markdown]
# Now let's add in a simple filter:

# %%
filter = '''
<netconf-yang/>
'''
c = m.get_config(source='running', filter=('subtree', filter))
pretty_print(c)
# Out:
# <data xmlns="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0">
#   <netconf-yang xmlns="http://cisco.com/yang/cisco-self-mgmt">
#     <cisco-ia xmlns="http://cisco.com/yang/cisco-ia">
#       <auto-sync>without-defaults</auto-sync>
#       <init-sync>without-defaults</init-sync>
#       <intelligent-sync>false</intelligent-sync>
#       <snmp-trap-control>
#         <global-forwarding>true</global-forwarding>
#         <trap-list>
#           <trap-oid>1.3.6.1.4.1.9.9.41.2.0.1</trap-oid>
#           <forward>true</forward>
#         </trap-list>
#         <trap-list>
#           <trap-oid>1.3.6.1.6.3.1.1.5.3</trap-oid>
#           <forward>true</forward>
#         </trap-list>
#         <trap-list>
#           <trap-oid>1.3.6.1.6.3.1.1.5.4</trap-oid>
#           <forward>true</forward>
#         </trap-list>
#       </snmp-trap-control>
#       <message-diag-level>0</message-diag-level>
#       <max-diag-messages-saved>30</max-diag-messages-saved>
#       <post-sync-acl-process>true</post-sync-acl-process>
#       <config-change-delay>0</config-change-delay>
#       <process-missing-prc>true</process-missing-prc>
#       <logging>
#         <confd-log-level>error</confd-log-level>
#         <ciaauthd-log-level>error</ciaauthd-log-level>
#         <nes-log-level>error</nes-log-level>
#         <onep-log-level>error</onep-log-level>
#         <odm-log-level>error</odm-log-level>
#         <sync-log-level>error</sync-log-level>
#       </logging>
#       <blocking>
#         <cli-blocking-enabled>false</cli-blocking-enabled>
#         <confd-cfg-blocking-enabled>true</confd-cfg-blocking-enabled>
#       </blocking>
#     </cisco-ia>
#     <cisco-odm xmlns="http://cisco.com/yang/cisco-odm">
#       <polling-enable>false</polling-enable>
#       <on-demand-default-time>30000</on-demand-default-time>
#       <on-demand-enable>false</on-demand-enable>
#       <actions>
#         <action-name>parse.showACL</action-name>
#         <polling-interval>120000</polling-interval>
#         <mode>poll</mode>
#       </actions>
#       <actions>
#         <action-name>parse.showArchive</action-name>
#         <polling-interval>120000</polling-interval>
#         <mode>poll</mode>
#       </actions>
#       <actions>
#         <action-name>parse.showBFDneighbors</action-name>
#         <polling-interval>120000</polling-interval>
#         <mode>poll</mode>
#       </actions>
#       <actions>
#         <action-name>parse.showBGP</action-name>
#         <polling-interval>120000</polling-interval>
#         <mode>poll</mode>
#       </actions>
#       <actions>
#         <action-name>parse.showBridgeDomain</action-name>
#         <polling-interval>120000</polling-interval>
#         <mode>poll</mode>
#       </actions>
#       <actions>
#         <action-name>parse.showEfpStatistics</action-name>
#         <polling-interval>120000</polling-interval>
#         <mode>poll</mode>
#       </actions>
#       <actions>
#         <action-name>parse.showEnvironment</action-name>
#         <polling-interval>120000</polling-interval>
#         <mode>poll</mode>
#       </actions>
#       <actions>
#         <action-name>parse.showEthernetCFMstatistics</action-name>
#         <polling-interval>120000</polling-interval>
#         <mode>poll</mode>
#       </actions>
#       <actions>
#         <action-name>parse.showFlowMonitor</action-name>
#         <polling-interval>120000</polling-interval>
#         <mode>poll</mode>
#       </actions>
#       <actions>
#         <action-name>parse.showIPslaStatistics</action-name>
#         <polling-interval>120000</polling-interval>
#         <mode>poll</mode>
#       </actions>
#       <actions>
#         <action-name>parse.showInterfaces</action-name>
#         <polling-interval>120000</polling-interval>
#         <mode>poll</mode>
#       </actions>
#       <actions>
#         <action-name>parse.showIpOspfDatabaseRouter</action-name>
#         <polling-interval>120000</polling-interval>
#         <mode>poll</mode>
#       </actions>
#       <actions>
#         <action-name>parse.showIpRoute</action-name>
#         <polling-interval>120000</polling-interval>
#         <mode>poll</mode>
#       </actions>
#       <actions>
#         <action-name>parse.showLLDPneighbors</action-name>
#         <polling-interval>120000</polling-interval>
#         <mode>poll</mode>
#       </actions>
#       <actions>
#         <action-name>parse.showMPLSforwardingTable</action-name>
#         <polling-interval>120000</polling-interval>
#         <mode>poll</mode>
#       </actions>
#       <actions>
#         <action-name>parse.showMPLSldpNieghbor</action-name>
#         <polling-interval>120000</polling-interval>
#         <mode>poll</mode>
#       </actions>
#       <actions>
#         <action-name>parse.showMPLSstaticBinding</action-name>
#         <polling-interval>120000</polling-interval>
#         <mode>poll</mode>
#       </actions>
#       <actions>
#         <action-name>parse.showMemoryStatistics</action-name>
#         <polling-interval>120000</polling-interval>
#         <mode>poll</mode>
#       </actions>
#       <actions>
#         <action-name>parse.showPlatformSoftware</action-name>
#         <polling-interval>120000</polling-interval>
#         <mode>poll</mode>
#       </actions>
#       <actions>
#         <action-name>parse.showProcessesCPU</action-name>
#         <polling-interval>120000</polling-interval>
#         <mode>poll</mode>
#       </actions>
#       <actions>
#         <action-name>parse.showProcessesMemory</action-name>
#         <polling-interval>120000</polling-interval>
#         <mode>poll</mode>
#       </actions>
#       <actions>
#         <action-name>parse.showVirtualService</action-name>
#         <polling-interval>120000</polling-interval>
#         <mode>poll</mode>
#       </actions>
#     </cisco-odm>
#   </netconf-yang>
# </data>

# %%
filter = '''
<native>
  <ip>
    <route/>
  </ip>
</native>
'''
c = m.get_config(source='running', filter=('subtree', filter))
pretty_print(c)
# Out:
# <data xmlns="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0">
#   <native xmlns="http://cisco.com/ns/yang/ned/ios">
#     <ip>
#       <route>
#         <ip-route-interface-forwarding-list>
#           <prefix>0.0.0.0</prefix>
#           <mask>0.0.0.0</mask>
#           <fwd-list>
#             <fwd>172.26.170.1</fwd>
#           </fwd-list>
#         </ip-route-interface-forwarding-list>
#         <vrf>
#           <name>Mgmt-vrf</name>
#           <ip-route-interface-forwarding-list>
#             <prefix>0.0.0.0</prefix>
#             <mask>0.0.0.0</mask>
#             <fwd-list>
#               <fwd>172.26.170.1</fwd>
#             </fwd-list>
#           </ip-route-interface-forwarding-list>
#         </vrf>
#       </route>
#     </ip>
#   </native>
# </data>

# %% [markdown]
# Now let's look at the BGP native model:

# %%
filter = '''
<native>
  <router>
    <bgp/>
  </router>
</native>
'''
c = m.get_config(source='running', filter=('subtree', filter))
pretty_print(c)
# Out:
# <data xmlns="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0">
#   <native xmlns="http://cisco.com/ns/yang/ned/ios">
#     <router>
#       <bgp>
#         <id>1</id>
#         <bgp>
#           <graceful-restart/>
#           <log-neighbor-changes/>
#         </bgp>
#         <neighbor>
#           <id>192.168.1.1</id>
#           <remote-as>666</remote-as>
#           <description>modified at 1466006302.11</description>
#           <ebgp-multihop>
#             <max-hop>255</max-hop>
#           </ebgp-multihop>
#         </neighbor>
#       </bgp>
#     </router>
#   </native>
# </data>

# %% [markdown]
# And can we look at a specific neighbor only? Say the one with id (address) '192.168.1.1'?

# %%
filter = '''
<native>
  <router>
    <bgp>
      <neighbor>
        <id>192.168.1.1</id>
      </neighbor>
    </bgp>
  </router>
</native>
'''
c = m.get_config(source='running', filter=('subtree', filter))
pretty_print(c)
# Out:
# <data xmlns="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0">
#   <native xmlns="http://cisco.com/ns/yang/ned/ios">
#     <router>
#       <bgp>
#         <neighbor>
#           <id>192.168.1.1</id>
#           <remote-as>666</remote-as>
#           <description>modified at 1466008798.62</description>
#           <ebgp-multihop>
#             <max-hop>255</max-hop>
#           </ebgp-multihop>
#         </neighbor>
#       </bgp>
#     </router>
#   </native>
# </data>

# %% [markdown]
# Ok, so, yes we can get a specific neighbor. Now, can we modify something in a neighbor? Let's keep it simple and modify the description:

# %%
import time
from ncclient.operations import TimeoutExpiredError

edit_data = '''
<config>
  <native xmlns="http://cisco.com/ns/yang/ned/ios">
    <router>
      <bgp>
        <id>1</id>
        <neighbor>
          <id>192.168.1.1</id>
          <description nc:operation="merge">modified at {}</description>
        </neighbor>
      </bgp>
    </router>
  </native>
</config>
'''.format(time.time())
try:
    edit_reply = m.edit_config(edit_data, target='running', format='xml')
except TimeoutExpiredError as e:
    print("Operation timeout!")
except Exception as e:
    print("severity={}, tag={}".format(e.severity, e.tag))
    print(e)

# %% [markdown]
# ## Other Stuff

# %% [markdown]
# Get interface data from native model:

# %%
filter = '''
<native>
  <interface>
    <GigabitEthernet>
      <name>1/0/1</name>
    </GigabitEthernet>
  </interface>
</native>
'''
c = m.get_config(source='running', filter=('subtree', filter))
pretty_print(c)
# Out:
# <data xmlns="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0">
#   <native xmlns="http://cisco.com/ns/yang/ned/ios">
#     <interface>
#       <GigabitEthernet>
#         <name>1/0/1</name>
#         <switchport-conf>
#           <switchport>false</switchport>
#         </switchport-conf>
#         <description>boom</description>
#         <ip>
#           <address>
#             <primary>
#               <address>1.1.1.1</address>
#               <mask>255.255.254.0</mask>
#             </primary>
#           </address>
#         </ip>
#       </GigabitEthernet>
#     </interface>
#   </native>
# </data>

# %% [markdown]
# Get aaa stuff:

# %%
filter = '''
<native>
  <aaa/>
</native>
'''
c = m.get_config(source='running', filter=('subtree', filter))
pretty_print(c)
# Out:
# <data xmlns="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0">
#   <native xmlns="http://cisco.com/ns/yang/ned/ios">
#     <aaa>
#       <new-model/>
#       <session-id>common</session-id>
#     </aaa>
#   </native>
# </data>
